# %% [markdown]
# <a href="https://colab.research.google.com/github/ekapolc/pattern_2022/blob/main/HW/HW07/HW7_Contrastive_learning_(student_version).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW 7 Contrastive learning
#
# This assignment aims to have you learn how to modify loss functions and simultaneously process multiple feature vectors in both face verification and face recognition tasks by using the CelebA dataset as an example.
#
# CelebFaces Attributes Dataset (CelebA) is a large-scale face attributes dataset with more than 200K celebrity images, each with 40 attribute annotations, covering a wide range of pose variations and background clutter. The dataset is pruned so that the training time is appropriate for the assignment.
#
# This homework is divided into three parts:
# 1. Face verification with contrastive loss
# 2. Face verification with triplet loss
# 3. Face verification evaluation

# %% [markdown]
# # Import main libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import os 
import os.path as osp 
from collections import defaultdict
from PIL import Image
import math 
from tqdm.notebook import tqdm 
import random

import torch 
from torch import nn 
import torch.nn.functional as F 
from torch import optim 
import torchvision 
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %% [markdown]
# #Download and unzip the dataset

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.63.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --id 1_2oATmA0Jw61qs7I7kAG9Q2LHNZSQX7A
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_2oATmA0Jw61qs7I7kAG9Q2LHNZSQX7A
# To: /content/large_prepared_data.zip
# 100% 23.4M/23.4M [00:00<00:00, 51.5MB/s]

# %%
# !unzip /content/large_prepared_data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: large_prepared_data/train/171636.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171636.jpg
#   inflating: large_prepared_data/train/061357.jpg
#   inflating: __MACOSX/large_prepared_data/train/._061357.jpg
#   inflating: large_prepared_data/train/033363.jpg
#   inflating: __MACOSX/large_prepared_data/train/._033363.jpg
#   inflating: large_prepared_data/train/110545.jpg
#   inflating: __MACOSX/large_prepared_data/train/._110545.jpg
#   inflating: large_prepared_data/train/084442.jpg
#   inflating: __MACOSX/large_prepared_data/train/._084442.jpg
#   inflating: large_prepared_data/train/140400.jpg
#   inflating: __MACOSX/large_prepared_data/train/._140400.jpg
#   inflating: large_prepared_data/train/005160.jpg
#   inflating: __MACOSX/large_prepared_data/train/._005160.jpg
#   inflating: large_prepared_data/train/110579.jpg
#   inflating: __MACOSX/large_prepared_data/train/._110579.jpg
#   inflating: large_prepared_data/train/174955.jpg
#   inflating: __MACOSX/large_prepared_data/train/._174955.jpg
#   inflating: large_prepared_data/train/088250.jpg
#   inflating: __MACOSX/large_prepared_data/train/._088250.jpg
#   inflating: large_prepared_data/train/061380.jpg
#   inflating: __MACOSX/large_prepared_data/train/._061380.jpg
#   inflating: large_prepared_data/train/176367.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176367.jpg
#   inflating: large_prepared_data/train/117955.jpg
#   inflating: __MACOSX/large_prepared_data/train/._117955.jpg
#   inflating: large_prepared_data/train/172101.jpg
#   inflating: __MACOSX/large_prepared_data/train/._172101.jpg
#   inflating: large_prepared_data/train/174216.jpg
#   inflating: __MACOSX/large_prepared_data/train/._174216.jpg
#   inflating: large_prepared_data/train/158924.jpg
#   inflating: __MACOSX/large_prepared_data/train/._158924.jpg
#   inflating: large_prepared_data/train/069521.jpg
#   inflating: __MACOSX/large_prepared_data/train/._069521.jpg
#   inflating: large_prepared_data/train/179040.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179040.jpg
#   inflating: large_prepared_data/train/155582.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155582.jpg
#   inflating: large_prepared_data/train/077051.jpg
#   inflating: __MACOSX/large_prepared_data/train/._077051.jpg
#   inflating: large_prepared_data/train/096522.jpg
#   inflating: __MACOSX/large_prepared_data/train/._096522.jpg
#   inflating: large_prepared_data/train/024390.jpg
#   inflating: __MACOSX/large_prepared_data/train/._024390.jpg
#   inflating: large_prepared_data/train/016444.jpg
#   inflating: __MACOSX/large_prepared_data/train/._016444.jpg
#   inflating: large_prepared_data/train/045008.jpg
#   inflating: __MACOSX/large_prepared_data/train/._045008.jpg
#   inflating: large_prepared_data/train/079929.jpg
#   inflating: __MACOSX/large_prepared_data/train/._079929.jpg
#   inflating: large_prepared_data/train/197600.jpg
#   inflating: __MACOSX/large_prepared_data/train/._197600.jpg
#   inflating: large_prepared_data/train/166000.jpg
#   inflating: __MACOSX/large_prepared_data/train/._166000.jpg
#   inflating: large_prepared_data/train/181843.jpg
#   inflating: __MACOSX/large_prepared_data/train/._181843.jpg
#   inflating: large_prepared_data/train/139276.jpg
#   inflating: __MACOSX/large_prepared_data/train/._139276.jpg
#   inflating: large_prepared_data/train/173357.jpg
#   inflating: __MACOSX/large_prepared_data/train/._173357.jpg
#   inflating: large_prepared_data/train/167444.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167444.jpg
#   inflating: large_prepared_data/train/127074.jpg
#   inflating: __MACOSX/large_prepared_data/train/._127074.jpg
#   inflating: large_prepared_data/train/009404.jpg
#   inflating: __MACOSX/large_prepared_data/train/._009404.jpg
#   inflating: large_prepared_data/train/158677.jpg
#   inflating: __MACOSX/large_prepared_data/train/._158677.jpg
#   inflating: large_prepared_data/train/167487.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167487.jpg
#   inflating: large_prepared_data/train/117174.jpg
#   inflating: __MACOSX/large_prepared_data/train/._117174.jpg
#   inflating: large_prepared_data/train/155347.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155347.jpg
#   inflating: large_prepared_data/train/182190.jpg
#   inflating: __MACOSX/large_prepared_data/train/._182190.jpg
#   inflating: large_prepared_data/train/007824.jpg
#   inflating: __MACOSX/large_prepared_data/train/._007824.jpg
#   inflating: large_prepared_data/train/122326.jpg
#   inflating: __MACOSX/large_prepared_data/train/._122326.jpg
#   inflating: large_prepared_data/train/064373.jpg
#   inflating: __MACOSX/large_prepared_data/train/._064373.jpg
#   inflating: large_prepared_data/train/139712.jpg
#   inflating: __MACOSX/large_prepared_data/train/._139712.jpg
#   inflating: large_prepared_data/train/134236.jpg
#   inflating: __MACOSX/large_prepared_data/train/._134236.jpg
#   inflating: large_prepared_data/train/116901.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116901.jpg
#   inflating: large_prepared_data/train/123762.jpg
#   inflating: __MACOSX/large_prepared_data/train/._123762.jpg
#   inflating: large_prepared_data/train/122468.jpg
#   inflating: __MACOSX/large_prepared_data/train/._122468.jpg
#   inflating: large_prepared_data/train/047596.jpg
#   inflating: __MACOSX/large_prepared_data/train/._047596.jpg
#   inflating: large_prepared_data/train/141695.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141695.jpg
#   inflating: large_prepared_data/train/171030.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171030.jpg
#   inflating: large_prepared_data/train/009821.jpg
#   inflating: __MACOSX/large_prepared_data/train/._009821.jpg
#   inflating: large_prepared_data/train/000150.jpg
#   inflating: __MACOSX/large_prepared_data/train/._000150.jpg
#   inflating: large_prepared_data/train/171965.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171965.jpg
#   inflating: large_prepared_data/train/156302.jpg
#   inflating: __MACOSX/large_prepared_data/train/._156302.jpg
#   inflating: large_prepared_data/train/078941.jpg
#   inflating: __MACOSX/large_prepared_data/train/._078941.jpg
#   inflating: large_prepared_data/train/069694.jpg
#   inflating: __MACOSX/large_prepared_data/train/._069694.jpg
#   inflating: large_prepared_data/train/118079.jpg
#   inflating: __MACOSX/large_prepared_data/train/._118079.jpg
#   inflating: large_prepared_data/train/155179.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155179.jpg
#   inflating: large_prepared_data/train/057034.jpg
#   inflating: __MACOSX/large_prepared_data/train/._057034.jpg
#   inflating: large_prepared_data/train/058307.jpg
#   inflating: __MACOSX/large_prepared_data/train/._058307.jpg
#   inflating: large_prepared_data/train/181300.jpg
#   inflating: __MACOSX/large_prepared_data/train/._181300.jpg
#   inflating: large_prepared_data/train/075295.jpg
#   inflating: __MACOSX/large_prepared_data/train/._075295.jpg
#   inflating: large_prepared_data/train/141656.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141656.jpg
#   inflating: large_prepared_data/train/095413.jpg
#   inflating: __MACOSX/large_prepared_data/train/._095413.jpg
#   inflating: large_prepared_data/train/167871.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167871.jpg
#   inflating: large_prepared_data/train/165928.jpg
#   inflating: __MACOSX/large_prepared_data/train/._165928.jpg
#   inflating: large_prepared_data/train/028182.jpg
#   inflating: __MACOSX/large_prepared_data/train/._028182.jpg
#   inflating: large_prepared_data/train/032657.jpg
#   inflating: __MACOSX/large_prepared_data/train/._032657.jpg
#   inflating: large_prepared_data/train/043910.jpg
#   inflating: __MACOSX/large_prepared_data/train/._043910.jpg
#   inflating: large_prepared_data/train/001289.jpg
#   inflating: __MACOSX/large_prepared_data/train/._001289.jpg
#   inflating: large_prepared_data/train/159948.jpg
#   inflating: __MACOSX/large_prepared_data/train/._159948.jpg
#   inflating: large_prepared_data/train/074158.jpg
#   inflating: __MACOSX/large_prepared_data/train/._074158.jpg
#   inflating: large_prepared_data/train/102964.jpg
#   inflating: __MACOSX/large_prepared_data/train/._102964.jpg
#   inflating: large_prepared_data/train/057781.jpg
#   inflating: __MACOSX/large_prepared_data/train/._057781.jpg
#   inflating: large_prepared_data/train/078776.jpg
#   inflating: __MACOSX/large_prepared_data/train/._078776.jpg
#   inflating: large_prepared_data/train/163342.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163342.jpg
#   inflating: large_prepared_data/train/138346.jpg
#   inflating: __MACOSX/large_prepared_data/train/._138346.jpg
#   inflating: large_prepared_data/train/169492.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169492.jpg
#   inflating: large_prepared_data/train/116246.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116246.jpg
#   inflating: large_prepared_data/train/103893.jpg
#   inflating: __MACOSX/large_prepared_data/train/._103893.jpg
#   inflating: large_prepared_data/train/189228.jpg
#   inflating: __MACOSX/large_prepared_data/train/._189228.jpg
#   inflating: large_prepared_data/train/053054.jpg
#   inflating: __MACOSX/large_prepared_data/train/._053054.jpg
#   inflating: large_prepared_data/train/061780.jpg
#   inflating: __MACOSX/large_prepared_data/train/._061780.jpg
#   inflating: large_prepared_data/train/169323.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169323.jpg
#   inflating: large_prepared_data/train/079642.jpg
#   inflating: __MACOSX/large_prepared_data/train/._079642.jpg
#   inflating: large_prepared_data/train/051870.jpg
#   inflating: __MACOSX/large_prepared_data/train/._051870.jpg
#   inflating: large_prepared_data/train/164161.jpg
#   inflating: __MACOSX/large_prepared_data/train/._164161.jpg
#   inflating: large_prepared_data/train/009399.jpg
#   inflating: __MACOSX/large_prepared_data/train/._009399.jpg
#   inflating: large_prepared_data/train/178574.jpg
#   inflating: __MACOSX/large_prepared_data/train/._178574.jpg
#   inflating: large_prepared_data/train/173353.jpg
#   inflating: __MACOSX/large_prepared_data/train/._173353.jpg
#   inflating: large_prepared_data/train/050401.jpg
#   inflating: __MACOSX/large_prepared_data/train/._050401.jpg
#   inflating: large_prepared_data/train/163975.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163975.jpg
#   inflating: large_prepared_data/train/035299.jpg
#   inflating: __MACOSX/large_prepared_data/train/._035299.jpg
#   inflating: large_prepared_data/train/091249.jpg
#   inflating: __MACOSX/large_prepared_data/train/._091249.jpg
#   inflating: large_prepared_data/train/127689.jpg
#   inflating: __MACOSX/large_prepared_data/train/._127689.jpg
#   inflating: large_prepared_data/train/152216.jpg
#   inflating: __MACOSX/large_prepared_data/train/._152216.jpg
#   inflating: large_prepared_data/train/007565.jpg
#   inflating: __MACOSX/large_prepared_data/train/._007565.jpg
#   inflating: large_prepared_data/train/005372.jpg
#   inflating: __MACOSX/large_prepared_data/train/._005372.jpg
#   inflating: large_prepared_data/train/168808.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168808.jpg
#   inflating: large_prepared_data/train/171381.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171381.jpg
#   inflating: large_prepared_data/train/187365.jpg
#   inflating: __MACOSX/large_prepared_data/train/._187365.jpg
#   inflating: large_prepared_data/train/113510.jpg
#   inflating: __MACOSX/large_prepared_data/train/._113510.jpg
#   inflating: large_prepared_data/train/072850.jpg
#   inflating: __MACOSX/large_prepared_data/train/._072850.jpg
#   inflating: large_prepared_data/train/177069.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177069.jpg
#   inflating: large_prepared_data/train/127886.jpg
#   inflating: __MACOSX/large_prepared_data/train/._127886.jpg
#   inflating: large_prepared_data/train/010958.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010958.jpg
#   inflating: large_prepared_data/train/029667.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029667.jpg
#   inflating: large_prepared_data/train/153861.jpg
#   inflating: __MACOSX/large_prepared_data/train/._153861.jpg
#   inflating: large_prepared_data/train/004093.jpg
#   inflating: __MACOSX/large_prepared_data/train/._004093.jpg
#   inflating: large_prepared_data/train/194494.jpg
#   inflating: __MACOSX/large_prepared_data/train/._194494.jpg
#   inflating: large_prepared_data/train/074560.jpg
#   inflating: __MACOSX/large_prepared_data/train/._074560.jpg
#   inflating: large_prepared_data/train/058934.jpg
#   inflating: __MACOSX/large_prepared_data/train/._058934.jpg
#   inflating: large_prepared_data/train/077727.jpg
#   inflating: __MACOSX/large_prepared_data/train/._077727.jpg
#   inflating: large_prepared_data/train/145959.jpg
#   inflating: __MACOSX/large_prepared_data/train/._145959.jpg
#   inflating: large_prepared_data/train/131766.jpg
#   inflating: __MACOSX/large_prepared_data/train/._131766.jpg
#   inflating: large_prepared_data/train/053685.jpg
#   inflating: __MACOSX/large_prepared_data/train/._053685.jpg
#   inflating: large_prepared_data/train/192973.jpg
#   inflating: __MACOSX/large_prepared_data/train/._192973.jpg
#   inflating: large_prepared_data/train/126568.jpg
#   inflating: __MACOSX/large_prepared_data/train/._126568.jpg
#   inflating: large_prepared_data/train/106860.jpg
#   inflating: __MACOSX/large_prepared_data/train/._106860.jpg
#   inflating: large_prepared_data/train/155586.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155586.jpg
#   inflating: large_prepared_data/train/150617.jpg
#   inflating: __MACOSX/large_prepared_data/train/._150617.jpg
#   inflating: large_prepared_data/train/200932.jpg
#   inflating: __MACOSX/large_prepared_data/train/._200932.jpg
#   inflating: large_prepared_data/train/130849.jpg
#   inflating: __MACOSX/large_prepared_data/train/._130849.jpg
#   inflating: large_prepared_data/train/144110.jpg
#   inflating: __MACOSX/large_prepared_data/train/._144110.jpg
#   inflating: large_prepared_data/train/088240.jpg
#   inflating: __MACOSX/large_prepared_data/train/._088240.jpg
#   inflating: large_prepared_data/train/153450.jpg
#   inflating: __MACOSX/large_prepared_data/train/._153450.jpg
#   inflating: large_prepared_data/train/079252.jpg
#   inflating: __MACOSX/large_prepared_data/train/._079252.jpg
#   inflating: large_prepared_data/train/010582.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010582.jpg
#   inflating: large_prepared_data/train/170504.jpg
#   inflating: __MACOSX/large_prepared_data/train/._170504.jpg
#   inflating: large_prepared_data/train/033367.jpg
#   inflating: __MACOSX/large_prepared_data/train/._033367.jpg
#   inflating: large_prepared_data/train/122518.jpg
#   inflating: __MACOSX/large_prepared_data/train/._122518.jpg
#   inflating: large_prepared_data/train/028021.jpg
#   inflating: __MACOSX/large_prepared_data/train/._028021.jpg
#   inflating: large_prepared_data/train/128747.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128747.jpg
#   inflating: large_prepared_data/train/194866.jpg
#   inflating: __MACOSX/large_prepared_data/train/._194866.jpg
#   inflating: large_prepared_data/train/141097.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141097.jpg
#   inflating: large_prepared_data/train/071626.jpg
#   inflating: __MACOSX/large_prepared_data/train/._071626.jpg
#   inflating: large_prepared_data/train/123613.jpg
#   inflating: __MACOSX/large_prepared_data/train/._123613.jpg
#   inflating: large_prepared_data/train/173756.jpg
#   inflating: __MACOSX/large_prepared_data/train/._173756.jpg
#   inflating: large_prepared_data/train/052954.jpg
#   inflating: __MACOSX/large_prepared_data/train/._052954.jpg
#   inflating: large_prepared_data/train/130135.jpg
#   inflating: __MACOSX/large_prepared_data/train/._130135.jpg
#   inflating: large_prepared_data/train/078159.jpg
#   inflating: __MACOSX/large_prepared_data/train/._078159.jpg
#   inflating: large_prepared_data/train/076174.jpg
#   inflating: __MACOSX/large_prepared_data/train/._076174.jpg
#   inflating: large_prepared_data/train/069040.jpg
#   inflating: __MACOSX/large_prepared_data/train/._069040.jpg
#   inflating: large_prepared_data/train/128008.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128008.jpg
#   inflating: large_prepared_data/train/139663.jpg
#   inflating: __MACOSX/large_prepared_data/train/._139663.jpg
#   inflating: large_prepared_data/train/147424.jpg
#   inflating: __MACOSX/large_prepared_data/train/._147424.jpg
#   inflating: large_prepared_data/train/165691.jpg
#   inflating: __MACOSX/large_prepared_data/train/._165691.jpg
#   inflating: large_prepared_data/train/154464.jpg
#   inflating: __MACOSX/large_prepared_data/train/._154464.jpg
#   inflating: large_prepared_data/train/167904.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167904.jpg
#   inflating: large_prepared_data/train/179284.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179284.jpg
#   inflating: large_prepared_data/train/131773.jpg
#   inflating: __MACOSX/large_prepared_data/train/._131773.jpg
#   inflating: large_prepared_data/train/049804.jpg
#   inflating: __MACOSX/large_prepared_data/train/._049804.jpg
#   inflating: large_prepared_data/train/168160.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168160.jpg
#   inflating: large_prepared_data/train/202315.jpg
#   inflating: __MACOSX/large_prepared_data/train/._202315.jpg
#   inflating: large_prepared_data/train/171425.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171425.jpg
#   inflating: large_prepared_data/train/067535.jpg
#   inflating: __MACOSX/large_prepared_data/train/._067535.jpg
#   inflating: large_prepared_data/train/125074.jpg
#   inflating: __MACOSX/large_prepared_data/train/._125074.jpg
#   inflating: large_prepared_data/train/045964.jpg
#   inflating: __MACOSX/large_prepared_data/train/._045964.jpg
#   inflating: large_prepared_data/train/179045.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179045.jpg
#   inflating: large_prepared_data/train/116482.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116482.jpg
#   inflating: large_prepared_data/train/139307.jpg
#   inflating: __MACOSX/large_prepared_data/train/._139307.jpg
#   inflating: large_prepared_data/train/131983.jpg
#   inflating: __MACOSX/large_prepared_data/train/._131983.jpg
#   inflating: large_prepared_data/train/029666.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029666.jpg
#   inflating: large_prepared_data/train/143440.jpg
#   inflating: __MACOSX/large_prepared_data/train/._143440.jpg
#   inflating: large_prepared_data/train/163948.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163948.jpg
#   inflating: large_prepared_data/train/189349.jpg
#   inflating: __MACOSX/large_prepared_data/train/._189349.jpg
#   inflating: large_prepared_data/train/076389.jpg
#   inflating: __MACOSX/large_prepared_data/train/._076389.jpg
#   inflating: large_prepared_data/train/171394.jpg
#   inflating: __MACOSX/large_prepared_data/train/._171394.jpg
#   inflating: large_prepared_data/train/053647.jpg
#   inflating: __MACOSX/large_prepared_data/train/._053647.jpg
#   inflating: large_prepared_data/train/186708.jpg
#   inflating: __MACOSX/large_prepared_data/train/._186708.jpg
#   inflating: large_prepared_data/train/195012.jpg
#   inflating: __MACOSX/large_prepared_data/train/._195012.jpg
#   inflating: large_prepared_data/train/063948.jpg
#   inflating: __MACOSX/large_prepared_data/train/._063948.jpg
#   inflating: large_prepared_data/train/198250.jpg
#   inflating: __MACOSX/large_prepared_data/train/._198250.jpg
#   inflating: large_prepared_data/train/092999.jpg
#   inflating: __MACOSX/large_prepared_data/train/._092999.jpg
#   inflating: large_prepared_data/train/069295.jpg
#   inflating: __MACOSX/large_prepared_data/train/._069295.jpg
#   inflating: large_prepared_data/train/084889.jpg
#   inflating: __MACOSX/large_prepared_data/train/._084889.jpg
#   inflating: large_prepared_data/train/116327.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116327.jpg
#   inflating: large_prepared_data/train/047785.jpg
#   inflating: __MACOSX/large_prepared_data/train/._047785.jpg
#   inflating: large_prepared_data/train/175051.jpg
#   inflating: __MACOSX/large_prepared_data/train/._175051.jpg
#   inflating: large_prepared_data/train/179643.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179643.jpg
#   inflating: large_prepared_data/train/102597.jpg
#   inflating: __MACOSX/large_prepared_data/train/._102597.jpg
#   inflating: large_prepared_data/train/194287.jpg
#   inflating: __MACOSX/large_prepared_data/train/._194287.jpg
#   inflating: large_prepared_data/train/132326.jpg
#   inflating: __MACOSX/large_prepared_data/train/._132326.jpg
#   inflating: large_prepared_data/train/061781.jpg
#   inflating: __MACOSX/large_prepared_data/train/._061781.jpg
#   inflating: large_prepared_data/train/183710.jpg
#   inflating: __MACOSX/large_prepared_data/train/._183710.jpg
#   inflating: large_prepared_data/train/163196.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163196.jpg
#   inflating: large_prepared_data/train/146458.jpg
#   inflating: __MACOSX/large_prepared_data/train/._146458.jpg
#   inflating: large_prepared_data/train/134794.jpg
#   inflating: __MACOSX/large_prepared_data/train/._134794.jpg
#   inflating: large_prepared_data/train/143093.jpg
#   inflating: __MACOSX/large_prepared_data/train/._143093.jpg
#   inflating: large_prepared_data/train/005950.jpg
#   inflating: __MACOSX/large_prepared_data/train/._005950.jpg
#   inflating: large_prepared_data/train/193932.jpg
#   inflating: __MACOSX/large_prepared_data/train/._193932.jpg
#   inflating: large_prepared_data/train/091857.jpg
#   inflating: __MACOSX/large_prepared_data/train/._091857.jpg
#   inflating: large_prepared_data/train/098126.jpg
#   inflating: __MACOSX/large_prepared_data/train/._098126.jpg
#   inflating: large_prepared_data/train/167680.jpg
#   inflating: __MACOSX/large_prepared_data/train/._167680.jpg
#   inflating: large_prepared_data/train/145353.jpg
#   inflating: __MACOSX/large_prepared_data/train/._145353.jpg
#   inflating: large_prepared_data/train/091116.jpg
#   inflating: __MACOSX/large_prepared_data/train/._091116.jpg
#   inflating: large_prepared_data/train/180999.jpg
#   inflating: __MACOSX/large_prepared_data/train/._180999.jpg
#   inflating: large_prepared_data/train/100633.jpg
#   inflating: __MACOSX/large_prepared_data/train/._100633.jpg
#   inflating: large_prepared_data/train/200853.jpg
#   inflating: __MACOSX/large_prepared_data/train/._200853.jpg
#   inflating: large_prepared_data/train/189771.jpg
#   inflating: __MACOSX/large_prepared_data/train/._189771.jpg
#   inflating: large_prepared_data/train/105985.jpg
#   inflating: __MACOSX/large_prepared_data/train/._105985.jpg
#   inflating: large_prepared_data/train/130080.jpg
#   inflating: __MACOSX/large_prepared_data/train/._130080.jpg
#   inflating: large_prepared_data/train/012221.jpg
#   inflating: __MACOSX/large_prepared_data/train/._012221.jpg
#   inflating: large_prepared_data/train/173807.jpg
#   inflating: __MACOSX/large_prepared_data/train/._173807.jpg
#   inflating: large_prepared_data/train/169687.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169687.jpg
#   inflating: large_prepared_data/train/146664.jpg
#   inflating: __MACOSX/large_prepared_data/train/._146664.jpg
#   inflating: large_prepared_data/train/081313.jpg
#   inflating: __MACOSX/large_prepared_data/train/._081313.jpg
#   inflating: large_prepared_data/train/058466.jpg
#   inflating: __MACOSX/large_prepared_data/train/._058466.jpg
#   inflating: large_prepared_data/train/155630.jpg
#   inflating: __MACOSX/large_prepared_data/train/._155630.jpg
#   inflating: large_prepared_data/train/169863.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169863.jpg
#   inflating: large_prepared_data/train/166588.jpg
#   inflating: __MACOSX/large_prepared_data/train/._166588.jpg
#   inflating: large_prepared_data/train/071786.jpg
#   inflating: __MACOSX/large_prepared_data/train/._071786.jpg
#   inflating: large_prepared_data/train/036426.jpg
#   inflating: __MACOSX/large_prepared_data/train/._036426.jpg
#   inflating: large_prepared_data/train/201226.jpg
#   inflating: __MACOSX/large_prepared_data/train/._201226.jpg
#   inflating: large_prepared_data/train/139067.jpg
#   inflating: __MACOSX/large_prepared_data/train/._139067.jpg
#   inflating: large_prepared_data/train/079457.jpg
#   inflating: __MACOSX/large_prepared_data/train/._079457.jpg
#   inflating: large_prepared_data/train/164406.jpg
#   inflating: __MACOSX/large_prepared_data/train/._164406.jpg
#   inflating: large_prepared_data/train/032654.jpg
#   inflating: __MACOSX/large_prepared_data/train/._032654.jpg
#   inflating: large_prepared_data/train/165056.jpg
#   inflating: __MACOSX/large_prepared_data/train/._165056.jpg
#   inflating: large_prepared_data/train/133210.jpg
#   inflating: __MACOSX/large_prepared_data/train/._133210.jpg
#   inflating: large_prepared_data/train/070329.jpg
#   inflating: __MACOSX/large_prepared_data/train/._070329.jpg
#   inflating: large_prepared_data/train/008286.jpg
#   inflating: __MACOSX/large_prepared_data/train/._008286.jpg
#   inflating: large_prepared_data/train/163433.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163433.jpg
#   inflating: large_prepared_data/train/009826.jpg
#   inflating: __MACOSX/large_prepared_data/train/._009826.jpg
#   inflating: large_prepared_data/train/082342.jpg
#   inflating: __MACOSX/large_prepared_data/train/._082342.jpg
#   inflating: large_prepared_data/train/047778.jpg
#   inflating: __MACOSX/large_prepared_data/train/._047778.jpg
#   inflating: large_prepared_data/train/144265.jpg
#   inflating: __MACOSX/large_prepared_data/train/._144265.jpg
#   inflating: large_prepared_data/train/016537.jpg
#   inflating: __MACOSX/large_prepared_data/train/._016537.jpg
#   inflating: large_prepared_data/train/054710.jpg
#   inflating: __MACOSX/large_prepared_data/train/._054710.jpg
#   inflating: large_prepared_data/train/048339.jpg
#   inflating: __MACOSX/large_prepared_data/train/._048339.jpg
#   inflating: large_prepared_data/train/051668.jpg
#   inflating: __MACOSX/large_prepared_data/train/._051668.jpg
#   inflating: large_prepared_data/train/054076.jpg
#   inflating: __MACOSX/large_prepared_data/train/._054076.jpg
#   inflating: large_prepared_data/train/017173.jpg
#   inflating: __MACOSX/large_prepared_data/train/._017173.jpg
#   inflating: large_prepared_data/train/140981.jpg
#   inflating: __MACOSX/large_prepared_data/train/._140981.jpg
#   inflating: large_prepared_data/train/063180.jpg
#   inflating: __MACOSX/large_prepared_data/train/._063180.jpg
#   inflating: large_prepared_data/train/119638.jpg
#   inflating: __MACOSX/large_prepared_data/train/._119638.jpg
#   inflating: large_prepared_data/train/066013.jpg
#   inflating: __MACOSX/large_prepared_data/train/._066013.jpg
#   inflating: large_prepared_data/train/116292.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116292.jpg
#   inflating: large_prepared_data/train/101936.jpg
#   inflating: __MACOSX/large_prepared_data/train/._101936.jpg
#   inflating: large_prepared_data/train/090949.jpg
#   inflating: __MACOSX/large_prepared_data/train/._090949.jpg
#   inflating: large_prepared_data/train/172066.jpg
#   inflating: __MACOSX/large_prepared_data/train/._172066.jpg
#   inflating: large_prepared_data/train/141484.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141484.jpg
#   inflating: large_prepared_data/train/128432.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128432.jpg
#   inflating: large_prepared_data/train/034769.jpg
#   inflating: __MACOSX/large_prepared_data/train/._034769.jpg
#   inflating: large_prepared_data/train/142833.jpg
#   inflating: __MACOSX/large_prepared_data/train/._142833.jpg
#   inflating: large_prepared_data/train/200306.jpg
#   inflating: __MACOSX/large_prepared_data/train/._200306.jpg
#   inflating: large_prepared_data/train/012976.jpg
#   inflating: __MACOSX/large_prepared_data/train/._012976.jpg
#   inflating: large_prepared_data/train/137260.jpg
#   inflating: __MACOSX/large_prepared_data/train/._137260.jpg
#   inflating: large_prepared_data/train/070881.jpg
#   inflating: __MACOSX/large_prepared_data/train/._070881.jpg
#   inflating: large_prepared_data/train/025670.jpg
#   inflating: __MACOSX/large_prepared_data/train/._025670.jpg
#   inflating: large_prepared_data/train/009205.jpg
#   inflating: __MACOSX/large_prepared_data/train/._009205.jpg
#   inflating: large_prepared_data/train/133827.jpg
#   inflating: __MACOSX/large_prepared_data/train/._133827.jpg
#   inflating: large_prepared_data/train/090140.jpg
#   inflating: __MACOSX/large_prepared_data/train/._090140.jpg
#   inflating: large_prepared_data/train/153679.jpg
#   inflating: __MACOSX/large_prepared_data/train/._153679.jpg
#   inflating: large_prepared_data/train/038972.jpg
#   inflating: __MACOSX/large_prepared_data/train/._038972.jpg
#   inflating: large_prepared_data/train/015610.jpg
#   inflating: __MACOSX/large_prepared_data/train/._015610.jpg
#   inflating: large_prepared_data/train/115610.jpg
#   inflating: __MACOSX/large_prepared_data/train/._115610.jpg
#   inflating: large_prepared_data/train/107214.jpg
#   inflating: __MACOSX/large_prepared_data/train/._107214.jpg
#   inflating: large_prepared_data/train/128591.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128591.jpg
#   inflating: large_prepared_data/train/173218.jpg
#   inflating: __MACOSX/large_prepared_data/train/._173218.jpg
#   inflating: large_prepared_data/train/078359.jpg
#   inflating: __MACOSX/large_prepared_data/train/._078359.jpg
#   inflating: large_prepared_data/train/082593.jpg
#   inflating: __MACOSX/large_prepared_data/train/._082593.jpg
#   inflating: large_prepared_data/train/038769.jpg
#   inflating: __MACOSX/large_prepared_data/train/._038769.jpg
#   inflating: large_prepared_data/train/136750.jpg
#   inflating: __MACOSX/large_prepared_data/train/._136750.jpg
#   inflating: large_prepared_data/train/151091.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151091.jpg
#   inflating: large_prepared_data/train/124368.jpg
#   inflating: __MACOSX/large_prepared_data/train/._124368.jpg
#   inflating: large_prepared_data/train/054472.jpg
#   inflating: __MACOSX/large_prepared_data/train/._054472.jpg
#   inflating: large_prepared_data/train/078198.jpg
#   inflating: __MACOSX/large_prepared_data/train/._078198.jpg
#   inflating: large_prepared_data/train/142204.jpg
#   inflating: __MACOSX/large_prepared_data/train/._142204.jpg
#   inflating: large_prepared_data/train/150600.jpg
#   inflating: __MACOSX/large_prepared_data/train/._150600.jpg
#   inflating: large_prepared_data/train/022282.jpg
#   inflating: __MACOSX/large_prepared_data/train/._022282.jpg
#   inflating: large_prepared_data/train/014730.jpg
#   inflating: __MACOSX/large_prepared_data/train/._014730.jpg
#   inflating: large_prepared_data/train/080637.jpg
#   inflating: __MACOSX/large_prepared_data/train/._080637.jpg
#   inflating: large_prepared_data/train/179286.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179286.jpg
#   inflating: large_prepared_data/train/081529.jpg
#   inflating: __MACOSX/large_prepared_data/train/._081529.jpg
#   inflating: large_prepared_data/train/112427.jpg
#   inflating: __MACOSX/large_prepared_data/train/._112427.jpg
#   inflating: large_prepared_data/train/122282.jpg
#   inflating: __MACOSX/large_prepared_data/train/._122282.jpg
#   inflating: large_prepared_data/train/018888.jpg
#   inflating: __MACOSX/large_prepared_data/train/._018888.jpg
#   inflating: large_prepared_data/train/007770.jpg
#   inflating: __MACOSX/large_prepared_data/train/._007770.jpg
#   inflating: large_prepared_data/train/005167.jpg
#   inflating: __MACOSX/large_prepared_data/train/._005167.jpg
#   inflating: large_prepared_data/train/132907.jpg
#   inflating: __MACOSX/large_prepared_data/train/._132907.jpg
#   inflating: large_prepared_data/train/001473.jpg
#   inflating: __MACOSX/large_prepared_data/train/._001473.jpg
#   inflating: large_prepared_data/train/193663.jpg
#   inflating: __MACOSX/large_prepared_data/train/._193663.jpg
#   inflating: large_prepared_data/train/147354.jpg
#   inflating: __MACOSX/large_prepared_data/train/._147354.jpg
#   inflating: large_prepared_data/train/162842.jpg
#   inflating: __MACOSX/large_prepared_data/train/._162842.jpg
#   inflating: large_prepared_data/train/105601.jpg
#   inflating: __MACOSX/large_prepared_data/train/._105601.jpg
#   inflating: large_prepared_data/train/029472.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029472.jpg
#   inflating: large_prepared_data/train/160066.jpg
#   inflating: __MACOSX/large_prepared_data/train/._160066.jpg
#   inflating: large_prepared_data/train/004286.jpg
#   inflating: __MACOSX/large_prepared_data/train/._004286.jpg
#   inflating: large_prepared_data/train/176162.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176162.jpg
#   inflating: large_prepared_data/train/062665.jpg
#   inflating: __MACOSX/large_prepared_data/train/._062665.jpg
#   inflating: large_prepared_data/train/136546.jpg
#   inflating: __MACOSX/large_prepared_data/train/._136546.jpg
#   inflating: large_prepared_data/train/029314.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029314.jpg
#   inflating: large_prepared_data/train/030645.jpg
#   inflating: __MACOSX/large_prepared_data/train/._030645.jpg
#   inflating: large_prepared_data/train/141902.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141902.jpg
#   inflating: large_prepared_data/train/170261.jpg
#   inflating: __MACOSX/large_prepared_data/train/._170261.jpg
#   inflating: large_prepared_data/train/121990.jpg
#   inflating: __MACOSX/large_prepared_data/train/._121990.jpg
#   inflating: large_prepared_data/train/124630.jpg
#   inflating: __MACOSX/large_prepared_data/train/._124630.jpg
#   inflating: large_prepared_data/train/199399.jpg
#   inflating: __MACOSX/large_prepared_data/train/._199399.jpg
#   inflating: large_prepared_data/train/154499.jpg
#   inflating: __MACOSX/large_prepared_data/train/._154499.jpg
#   inflating: large_prepared_data/train/128744.jpg
#   inflating: __MACOSX/large_prepared_data/train/._128744.jpg
#   inflating: large_prepared_data/train/037664.jpg
#   inflating: __MACOSX/large_prepared_data/train/._037664.jpg
#   inflating: large_prepared_data/train/175325.jpg
#   inflating: __MACOSX/large_prepared_data/train/._175325.jpg
#   inflating: large_prepared_data/train/037103.jpg
#   inflating: __MACOSX/large_prepared_data/train/._037103.jpg
#   inflating: large_prepared_data/train/076639.jpg
#   inflating: __MACOSX/large_prepared_data/train/._076639.jpg
#   inflating: large_prepared_data/train/177255.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177255.jpg
#   inflating: large_prepared_data/train/175330.jpg
#   inflating: __MACOSX/large_prepared_data/train/._175330.jpg
#   inflating: large_prepared_data/train/154498.jpg
#   inflating: __MACOSX/large_prepared_data/train/._154498.jpg
#   inflating: large_prepared_data/train/014094.jpg
#   inflating: __MACOSX/large_prepared_data/train/._014094.jpg
#   inflating: large_prepared_data/train/129301.jpg
#   inflating: __MACOSX/large_prepared_data/train/._129301.jpg
#   inflating: large_prepared_data/train/135728.jpg
#   inflating: __MACOSX/large_prepared_data/train/._135728.jpg
#   inflating: large_prepared_data/train/010594.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010594.jpg
#   inflating: large_prepared_data/train/013076.jpg
#   inflating: __MACOSX/large_prepared_data/train/._013076.jpg
#   inflating: large_prepared_data/train/158275.jpg
#   inflating: __MACOSX/large_prepared_data/train/._158275.jpg
#   inflating: large_prepared_data/train/097376.jpg
#   inflating: __MACOSX/large_prepared_data/train/._097376.jpg
#   inflating: large_prepared_data/train/095561.jpg
#   inflating: __MACOSX/large_prepared_data/train/._095561.jpg
#   inflating: large_prepared_data/train/085014.jpg
#   inflating: __MACOSX/large_prepared_data/train/._085014.jpg
#   inflating: large_prepared_data/train/147427.jpg
#   inflating: __MACOSX/large_prepared_data/train/._147427.jpg
#   inflating: large_prepared_data/train/024816.jpg
#   inflating: __MACOSX/large_prepared_data/train/._024816.jpg
#   inflating: large_prepared_data/train/037842.jpg
#   inflating: __MACOSX/large_prepared_data/train/._037842.jpg
#   inflating: large_prepared_data/train/050173.jpg
#   inflating: __MACOSX/large_prepared_data/train/._050173.jpg
#   inflating: large_prepared_data/train/133173.jpg
#   inflating: __MACOSX/large_prepared_data/train/._133173.jpg
#   inflating: large_prepared_data/train/108683.jpg
#   inflating: __MACOSX/large_prepared_data/train/._108683.jpg
#   inflating: large_prepared_data/train/129895.jpg
#   inflating: __MACOSX/large_prepared_data/train/._129895.jpg
#   inflating: large_prepared_data/train/192971.jpg
#   inflating: __MACOSX/large_prepared_data/train/._192971.jpg
#   inflating: large_prepared_data/train/178416.jpg
#   inflating: __MACOSX/large_prepared_data/train/._178416.jpg
#   inflating: large_prepared_data/train/020899.jpg
#   inflating: __MACOSX/large_prepared_data/train/._020899.jpg
#   inflating: large_prepared_data/train/176375.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176375.jpg
#   inflating: large_prepared_data/train/074589.jpg
#   inflating: __MACOSX/large_prepared_data/train/._074589.jpg
#   inflating: large_prepared_data/train/108640.jpg
#   inflating: __MACOSX/large_prepared_data/train/._108640.jpg
#   inflating: large_prepared_data/train/188054.jpg
#   inflating: __MACOSX/large_prepared_data/train/._188054.jpg
#   inflating: large_prepared_data/train/018453.jpg
#   inflating: __MACOSX/large_prepared_data/train/._018453.jpg
#   inflating: large_prepared_data/train/130485.jpg
#   inflating: __MACOSX/large_prepared_data/train/._130485.jpg
#   inflating: large_prepared_data/train/168188.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168188.jpg
#   inflating: large_prepared_data/train/050365.jpg
#   inflating: __MACOSX/large_prepared_data/train/._050365.jpg
#   inflating: large_prepared_data/train/010999.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010999.jpg
#   inflating: large_prepared_data/train/014255.jpg
#   inflating: __MACOSX/large_prepared_data/train/._014255.jpg
#   inflating: large_prepared_data/train/068017.jpg
#   inflating: __MACOSX/large_prepared_data/train/._068017.jpg
#   inflating: large_prepared_data/train/177645.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177645.jpg
#   inflating: large_prepared_data/train/131176.jpg
#   inflating: __MACOSX/large_prepared_data/train/._131176.jpg
#   inflating: large_prepared_data/train/168003.jpg
#   inflating: __MACOSX/large_prepared_data/train/._168003.jpg
#   inflating: large_prepared_data/train/163156.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163156.jpg
#   inflating: large_prepared_data/train/055382.jpg
#   inflating: __MACOSX/large_prepared_data/train/._055382.jpg
#   inflating: large_prepared_data/train/176567.jpg
#   inflating: __MACOSX/large_prepared_data/train/._176567.jpg
#   inflating: large_prepared_data/train/032457.jpg
#   inflating: __MACOSX/large_prepared_data/train/._032457.jpg
#   inflating: large_prepared_data/train/151866.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151866.jpg
#   inflating: large_prepared_data/train/170670.jpg
#   inflating: __MACOSX/large_prepared_data/train/._170670.jpg
#   inflating: large_prepared_data/train/038185.jpg
#   inflating: __MACOSX/large_prepared_data/train/._038185.jpg
#   inflating: large_prepared_data/train/141452.jpg
#   inflating: __MACOSX/large_prepared_data/train/._141452.jpg
#   inflating: large_prepared_data/train/181104.jpg
#   inflating: __MACOSX/large_prepared_data/train/._181104.jpg
#   inflating: large_prepared_data/train/088652.jpg
#   inflating: __MACOSX/large_prepared_data/train/._088652.jpg
#   inflating: large_prepared_data/train/084040.jpg
#   inflating: __MACOSX/large_prepared_data/train/._084040.jpg
#   inflating: large_prepared_data/train/194247.jpg
#   inflating: __MACOSX/large_prepared_data/train/._194247.jpg
#   inflating: large_prepared_data/train/127933.jpg
#   inflating: __MACOSX/large_prepared_data/train/._127933.jpg
#   inflating: large_prepared_data/train/050211.jpg
#   inflating: __MACOSX/large_prepared_data/train/._050211.jpg
#   inflating: large_prepared_data/train/069484.jpg
#   inflating: __MACOSX/large_prepared_data/train/._069484.jpg
#   inflating: large_prepared_data/train/151480.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151480.jpg
#   inflating: large_prepared_data/train/131374.jpg
#   inflating: __MACOSX/large_prepared_data/train/._131374.jpg
#   inflating: large_prepared_data/train/000817.jpg
#   inflating: __MACOSX/large_prepared_data/train/._000817.jpg
#   inflating: large_prepared_data/train/018902.jpg
#   inflating: __MACOSX/large_prepared_data/train/._018902.jpg
#   inflating: large_prepared_data/train/045344.jpg
#   inflating: __MACOSX/large_prepared_data/train/._045344.jpg
#   inflating: large_prepared_data/train/065094.jpg
#   inflating: __MACOSX/large_prepared_data/train/._065094.jpg
#   inflating: large_prepared_data/train/047235.jpg
#   inflating: __MACOSX/large_prepared_data/train/._047235.jpg
#   inflating: large_prepared_data/train/197216.jpg
#   inflating: __MACOSX/large_prepared_data/train/._197216.jpg
#   inflating: large_prepared_data/train/075293.jpg
#   inflating: __MACOSX/large_prepared_data/train/._075293.jpg
#   inflating: large_prepared_data/train/156310.jpg
#   inflating: __MACOSX/large_prepared_data/train/._156310.jpg
#   inflating: large_prepared_data/train/004442.jpg
#   inflating: __MACOSX/large_prepared_data/train/._004442.jpg
#   inflating: large_prepared_data/train/182155.jpg
#   inflating: __MACOSX/large_prepared_data/train/._182155.jpg
#   inflating: large_prepared_data/train/075592.jpg
#   inflating: __MACOSX/large_prepared_data/train/._075592.jpg
#   inflating: large_prepared_data/train/153541.jpg
#   inflating: __MACOSX/large_prepared_data/train/._153541.jpg
#   inflating: large_prepared_data/train/052893.jpg
#   inflating: __MACOSX/large_prepared_data/train/._052893.jpg
#   inflating: large_prepared_data/train/098156.jpg
#   inflating: __MACOSX/large_prepared_data/train/._098156.jpg
#   inflating: large_prepared_data/train/049519.jpg
#   inflating: __MACOSX/large_prepared_data/train/._049519.jpg
#   inflating: large_prepared_data/train/003410.jpg
#   inflating: __MACOSX/large_prepared_data/train/._003410.jpg
#   inflating: large_prepared_data/train/000131.jpg
#   inflating: __MACOSX/large_prepared_data/train/._000131.jpg
#   inflating: large_prepared_data/train/144001.jpg
#   inflating: __MACOSX/large_prepared_data/train/._144001.jpg
#   inflating: large_prepared_data/train/006540.jpg
#   inflating: __MACOSX/large_prepared_data/train/._006540.jpg
#   inflating: large_prepared_data/train/136497.jpg
#   inflating: __MACOSX/large_prepared_data/train/._136497.jpg
#   inflating: large_prepared_data/train/200823.jpg
#   inflating: __MACOSX/large_prepared_data/train/._200823.jpg
#   inflating: large_prepared_data/train/010450.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010450.jpg
#   inflating: large_prepared_data/train/146164.jpg
#   inflating: __MACOSX/large_prepared_data/train/._146164.jpg
#   inflating: large_prepared_data/train/177434.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177434.jpg
#   inflating: large_prepared_data/train/116974.jpg
#   inflating: __MACOSX/large_prepared_data/train/._116974.jpg
#   inflating: large_prepared_data/train/177420.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177420.jpg
#   inflating: large_prepared_data/train/179425.jpg
#   inflating: __MACOSX/large_prepared_data/train/._179425.jpg
#   inflating: large_prepared_data/train/132154.jpg
#   inflating: __MACOSX/large_prepared_data/train/._132154.jpg
#   inflating: large_prepared_data/train/014839.jpg
#   inflating: __MACOSX/large_prepared_data/train/._014839.jpg
#   inflating: large_prepared_data/train/163469.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163469.jpg
#   inflating: large_prepared_data/train/041804.jpg
#   inflating: __MACOSX/large_prepared_data/train/._041804.jpg
#   inflating: large_prepared_data/train/151632.jpg
#   inflating: __MACOSX/large_prepared_data/train/._151632.jpg
#   inflating: large_prepared_data/train/029945.jpg
#   inflating: __MACOSX/large_prepared_data/train/._029945.jpg
#   inflating: large_prepared_data/train/043222.jpg
#   inflating: __MACOSX/large_prepared_data/train/._043222.jpg
#   inflating: large_prepared_data/train/164845.jpg
#   inflating: __MACOSX/large_prepared_data/train/._164845.jpg
#   inflating: large_prepared_data/train/095670.jpg
#   inflating: __MACOSX/large_prepared_data/train/._095670.jpg
#   inflating: large_prepared_data/train/011558.jpg
#   inflating: __MACOSX/large_prepared_data/train/._011558.jpg
#   inflating: large_prepared_data/train/169391.jpg
#   inflating: __MACOSX/large_prepared_data/train/._169391.jpg
#   inflating: large_prepared_data/train/154010.jpg
#   inflating: __MACOSX/large_prepared_data/train/._154010.jpg
#   inflating: large_prepared_data/train/101993.jpg
#   inflating: __MACOSX/large_prepared_data/train/._101993.jpg
#   inflating: large_prepared_data/train/057519.jpg
#   inflating: __MACOSX/large_prepared_data/train/._057519.jpg
#   inflating: large_prepared_data/train/163125.jpg
#   inflating: __MACOSX/large_prepared_data/train/._163125.jpg
#   inflating: large_prepared_data/train/177636.jpg
#   inflating: __MACOSX/large_prepared_data/train/._177636.jpg
#   inflating: large_prepared_data/train/018583.jpg
#   inflating: __MACOSX/large_prepared_data/train/._018583.jpg
#   inflating: large_prepared_data/train/021316.jpg
#   inflating: __MACOSX/large_prepared_data/train/._021316.jpg
#   inflating: large_prepared_data/train/117840.jpg
#   inflating: __MACOSX/large_prepared_data/train/._117840.jpg
#   inflating: large_prepared_data/train/101944.jpg
#   inflating: __MACOSX/large_prepared_data/train/._101944.jpg
#   inflating: large_prepared_data/train/090091.jpg
#   inflating: __MACOSX/large_prepared_data/train/._090091.jpg
#   inflating: large_prepared_data/train/024252.jpg
#   inflating: __MACOSX/large_prepared_data/train/._024252.jpg
#   inflating: large_prepared_data/train/181836.jpg
#   inflating: __MACOSX/large_prepared_data/train/._181836.jpg
#   inflating: large_prepared_data/train/104196.jpg
#   inflating: __MACOSX/large_prepared_data/train/._104196.jpg
#   inflating: large_prepared_data/train/001603.jpg
#   inflating: __MACOSX/large_prepared_data/train/._001603.jpg
#   inflating: large_prepared_data/train/010068.jpg
#   inflating: __MACOSX/large_prepared_data/train/._010068.jpg
#   inflating: large_prepared_data/train/165385.jpg
#   inflating: __MACOSX/large_prepared_data/train/._165385.jpg
#   inflating: large_prepared_data/train/118352.jpg
#   inflating: __MACOSX/large_prepared_data/train/._118352.jpg
#   inflating: large_prepared_data/train/017075.jpg
#   inflating: __MACOSX/large_prepared_data/train/._017075.jpg
#   inflating: large_prepared_data/train/052501.jpg
#   inflating: __MACOSX/large_prepared_data/train/._052501.jpg
#   inflating: large_prepared_data/train/166868.jpg
#   inflating: __MACOSX/large_prepared_data/train/._166868.jpg
#   inflating: large_prepared_data/train/085259.jpg
#   inflating: __MACOSX/large_prepared_data/train/._085259.jpg
#   inflating: large_prepared_data/train/002444.jpg
# ...
#   inflating: large_prepared_data/val/060141.jpg
#   inflating: __MACOSX/large_prepared_data/val/._060141.jpg
#   inflating: large_prepared_data/val/111551.jpg
#   inflating: __MACOSX/large_prepared_data/val/._111551.jpg
#   inflating: large_prepared_data/val/125186.jpg
#   inflating: __MACOSX/large_prepared_data/val/._125186.jpg
#   inflating: large_prepared_data/val/197132.jpg
#   inflating: __MACOSX/large_prepared_data/val/._197132.jpg
#   inflating: large_prepared_data/val/022762.jpg
#   inflating: __MACOSX/large_prepared_data/val/._022762.jpg
#   inflating: large_prepared_data/val/202152.jpg
#   inflating: __MACOSX/large_prepared_data/val/._202152.jpg
#   inflating: large_prepared_data/val/011182.jpg
#   inflating: __MACOSX/large_prepared_data/val/._011182.jpg
#   inflating: large_prepared_data/val/005690.jpg
#   inflating: __MACOSX/large_prepared_data/val/._005690.jpg
#   inflating: large_prepared_data/val/001421.jpg
#   inflating: __MACOSX/large_prepared_data/val/._001421.jpg
#   inflating: large_prepared_data/val/042915.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042915.jpg
#   inflating: large_prepared_data/val/053617.jpg
#   inflating: __MACOSX/large_prepared_data/val/._053617.jpg
#   inflating: large_prepared_data/val/139579.jpg
#   inflating: __MACOSX/large_prepared_data/val/._139579.jpg
#   inflating: large_prepared_data/val/192467.jpg
#   inflating: __MACOSX/large_prepared_data/val/._192467.jpg
#   inflating: large_prepared_data/val/045465.jpg
#   inflating: __MACOSX/large_prepared_data/val/._045465.jpg
#   inflating: large_prepared_data/val/141173.jpg
#   inflating: __MACOSX/large_prepared_data/val/._141173.jpg
#   inflating: large_prepared_data/val/105731.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105731.jpg
#   inflating: large_prepared_data/val/105057.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105057.jpg
#   inflating: large_prepared_data/val/020994.jpg
#   inflating: __MACOSX/large_prepared_data/val/._020994.jpg
#   inflating: large_prepared_data/val/009241.jpg
#   inflating: __MACOSX/large_prepared_data/val/._009241.jpg
#   inflating: large_prepared_data/val/040872.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040872.jpg
#   inflating: large_prepared_data/val/085284.jpg
#   inflating: __MACOSX/large_prepared_data/val/._085284.jpg
#   inflating: large_prepared_data/val/065370.jpg
#   inflating: __MACOSX/large_prepared_data/val/._065370.jpg
#   inflating: large_prepared_data/val/014748.jpg
#   inflating: __MACOSX/large_prepared_data/val/._014748.jpg
#   inflating: large_prepared_data/val/104567.jpg
#   inflating: __MACOSX/large_prepared_data/val/._104567.jpg
#   inflating: large_prepared_data/val/156547.jpg
#   inflating: __MACOSX/large_prepared_data/val/._156547.jpg
#   inflating: large_prepared_data/val/004201.jpg
#   inflating: __MACOSX/large_prepared_data/val/._004201.jpg
#   inflating: large_prepared_data/val/127433.jpg
#   inflating: __MACOSX/large_prepared_data/val/._127433.jpg
#   inflating: large_prepared_data/val/022984.jpg
#   inflating: __MACOSX/large_prepared_data/val/._022984.jpg
#   inflating: large_prepared_data/val/090139.jpg
#   inflating: __MACOSX/large_prepared_data/val/._090139.jpg
#   inflating: large_prepared_data/val/038328.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038328.jpg
#   inflating: large_prepared_data/val/050902.jpg
#   inflating: __MACOSX/large_prepared_data/val/._050902.jpg
#   inflating: large_prepared_data/val/089722.jpg
#   inflating: __MACOSX/large_prepared_data/val/._089722.jpg
#   inflating: large_prepared_data/val/040522.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040522.jpg
#   inflating: large_prepared_data/val/155665.jpg
#   inflating: __MACOSX/large_prepared_data/val/._155665.jpg
#   inflating: large_prepared_data/val/105734.jpg
#   inflating: __MACOSX/large_prepared_data/val/._105734.jpg
#   inflating: large_prepared_data/val/132167.jpg
#   inflating: __MACOSX/large_prepared_data/val/._132167.jpg
#   inflating: large_prepared_data/val/054962.jpg
#   inflating: __MACOSX/large_prepared_data/val/._054962.jpg
#   inflating: large_prepared_data/val/187455.jpg
#   inflating: __MACOSX/large_prepared_data/val/._187455.jpg
#   inflating: large_prepared_data/val/038258.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038258.jpg
#   inflating: large_prepared_data/val/117251.jpg
#   inflating: __MACOSX/large_prepared_data/val/._117251.jpg
#   inflating: large_prepared_data/val/150126.jpg
#   inflating: __MACOSX/large_prepared_data/val/._150126.jpg
#   inflating: large_prepared_data/val/076268.jpg
#   inflating: __MACOSX/large_prepared_data/val/._076268.jpg
#   inflating: large_prepared_data/val/006770.jpg
#   inflating: __MACOSX/large_prepared_data/val/._006770.jpg
#   inflating: large_prepared_data/val/036114.jpg
#   inflating: __MACOSX/large_prepared_data/val/._036114.jpg
#   inflating: large_prepared_data/val/135353.jpg
#   inflating: __MACOSX/large_prepared_data/val/._135353.jpg
#   inflating: large_prepared_data/val/183618.jpg
#   inflating: __MACOSX/large_prepared_data/val/._183618.jpg
#   inflating: large_prepared_data/val/104993.jpg
#   inflating: __MACOSX/large_prepared_data/val/._104993.jpg
#   inflating: large_prepared_data/val/065148.jpg
#   inflating: __MACOSX/large_prepared_data/val/._065148.jpg
#   inflating: large_prepared_data/val/131243.jpg
#   inflating: __MACOSX/large_prepared_data/val/._131243.jpg
#   inflating: large_prepared_data/val/040487.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040487.jpg
#   inflating: large_prepared_data/val/122216.jpg
#   inflating: __MACOSX/large_prepared_data/val/._122216.jpg
#   inflating: large_prepared_data/val/001342.jpg
#   inflating: __MACOSX/large_prepared_data/val/._001342.jpg
#   inflating: large_prepared_data/val/049460.jpg
#   inflating: __MACOSX/large_prepared_data/val/._049460.jpg
#   inflating: large_prepared_data/val/018439.jpg
#   inflating: __MACOSX/large_prepared_data/val/._018439.jpg
#   inflating: large_prepared_data/val/149676.jpg
#   inflating: __MACOSX/large_prepared_data/val/._149676.jpg
#   inflating: large_prepared_data/val/039385.jpg
#   inflating: __MACOSX/large_prepared_data/val/._039385.jpg
#   inflating: large_prepared_data/val/140915.jpg
#   inflating: __MACOSX/large_prepared_data/val/._140915.jpg
#   inflating: large_prepared_data/val/019874.jpg
#   inflating: __MACOSX/large_prepared_data/val/._019874.jpg
#   inflating: large_prepared_data/val/011582.jpg
#   inflating: __MACOSX/large_prepared_data/val/._011582.jpg
#   inflating: large_prepared_data/val/120763.jpg
#   inflating: __MACOSX/large_prepared_data/val/._120763.jpg
#   inflating: large_prepared_data/val/079164.jpg
#   inflating: __MACOSX/large_prepared_data/val/._079164.jpg
#   inflating: large_prepared_data/val/119135.jpg
#   inflating: __MACOSX/large_prepared_data/val/._119135.jpg
#   inflating: large_prepared_data/val/015218.jpg
#   inflating: __MACOSX/large_prepared_data/val/._015218.jpg
#   inflating: large_prepared_data/val/200120.jpg
#   inflating: __MACOSX/large_prepared_data/val/._200120.jpg
#   inflating: large_prepared_data/val/028358.jpg
#   inflating: __MACOSX/large_prepared_data/val/._028358.jpg
#   inflating: large_prepared_data/val/077099.jpg
#   inflating: __MACOSX/large_prepared_data/val/._077099.jpg
#   inflating: large_prepared_data/val/152769.jpg
#   inflating: __MACOSX/large_prepared_data/val/._152769.jpg
#   inflating: large_prepared_data/val/007998.jpg
#   inflating: __MACOSX/large_prepared_data/val/._007998.jpg
#   inflating: large_prepared_data/val/148725.jpg
#   inflating: __MACOSX/large_prepared_data/val/._148725.jpg
#   inflating: large_prepared_data/val/194128.jpg
#   inflating: __MACOSX/large_prepared_data/val/._194128.jpg
#   inflating: large_prepared_data/val/021750.jpg
#   inflating: __MACOSX/large_prepared_data/val/._021750.jpg
#   inflating: large_prepared_data/val/069066.jpg
#   inflating: __MACOSX/large_prepared_data/val/._069066.jpg
#   inflating: large_prepared_data/val/085965.jpg
#   inflating: __MACOSX/large_prepared_data/val/._085965.jpg
#   inflating: large_prepared_data/val/000984.jpg
#   inflating: __MACOSX/large_prepared_data/val/._000984.jpg
#   inflating: large_prepared_data/val/186908.jpg
#   inflating: __MACOSX/large_prepared_data/val/._186908.jpg
#   inflating: large_prepared_data/val/052230.jpg
#   inflating: __MACOSX/large_prepared_data/val/._052230.jpg
#   inflating: large_prepared_data/val/132473.jpg
#   inflating: __MACOSX/large_prepared_data/val/._132473.jpg
#   inflating: large_prepared_data/val/114852.jpg
#   inflating: __MACOSX/large_prepared_data/val/._114852.jpg
#   inflating: large_prepared_data/val/059761.jpg
#   inflating: __MACOSX/large_prepared_data/val/._059761.jpg
#   inflating: large_prepared_data/val/086303.jpg
#   inflating: __MACOSX/large_prepared_data/val/._086303.jpg
#   inflating: large_prepared_data/val/141660.jpg
#   inflating: __MACOSX/large_prepared_data/val/._141660.jpg
#   inflating: large_prepared_data/val/129253.jpg
#   inflating: __MACOSX/large_prepared_data/val/._129253.jpg
#   inflating: large_prepared_data/val/038955.jpg
#   inflating: __MACOSX/large_prepared_data/val/._038955.jpg
#   inflating: large_prepared_data/val/052226.jpg
#   inflating: __MACOSX/large_prepared_data/val/._052226.jpg
#   inflating: large_prepared_data/val/076409.jpg
#   inflating: __MACOSX/large_prepared_data/val/._076409.jpg
#   inflating: large_prepared_data/val/008464.jpg
#   inflating: __MACOSX/large_prepared_data/val/._008464.jpg
#   inflating: large_prepared_data/val/063212.jpg
#   inflating: __MACOSX/large_prepared_data/val/._063212.jpg
#   inflating: large_prepared_data/val/134362.jpg
#   inflating: __MACOSX/large_prepared_data/val/._134362.jpg
#   inflating: large_prepared_data/val/201361.jpg
#   inflating: __MACOSX/large_prepared_data/val/._201361.jpg
#   inflating: large_prepared_data/val/060726.jpg
#   inflating: __MACOSX/large_prepared_data/val/._060726.jpg
#   inflating: large_prepared_data/val/121746.jpg
#   inflating: __MACOSX/large_prepared_data/val/._121746.jpg
#   inflating: large_prepared_data/val/110558.jpg
#   inflating: __MACOSX/large_prepared_data/val/._110558.jpg
#   inflating: large_prepared_data/val/047825.jpg
#   inflating: __MACOSX/large_prepared_data/val/._047825.jpg
#   inflating: large_prepared_data/val/147819.jpg
#   inflating: __MACOSX/large_prepared_data/val/._147819.jpg
#   inflating: large_prepared_data/val/137454.jpg
#   inflating: __MACOSX/large_prepared_data/val/._137454.jpg
#   inflating: large_prepared_data/val/096271.jpg
#   inflating: __MACOSX/large_prepared_data/val/._096271.jpg
#   inflating: large_prepared_data/val/073404.jpg
#   inflating: __MACOSX/large_prepared_data/val/._073404.jpg
#   inflating: large_prepared_data/val/189225.jpg
#   inflating: __MACOSX/large_prepared_data/val/._189225.jpg
#   inflating: large_prepared_data/val/140582.jpg
#   inflating: __MACOSX/large_prepared_data/val/._140582.jpg
#   inflating: large_prepared_data/val/122313.jpg
#   inflating: __MACOSX/large_prepared_data/val/._122313.jpg
#   inflating: large_prepared_data/val/035647.jpg
#   inflating: __MACOSX/large_prepared_data/val/._035647.jpg
#   inflating: large_prepared_data/val/042424.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042424.jpg
#   inflating: large_prepared_data/val/159969.jpg
#   inflating: __MACOSX/large_prepared_data/val/._159969.jpg
#   inflating: large_prepared_data/val/027521.jpg
#   inflating: __MACOSX/large_prepared_data/val/._027521.jpg
#   inflating: large_prepared_data/val/068544.jpg
#   inflating: __MACOSX/large_prepared_data/val/._068544.jpg
#   inflating: large_prepared_data/val/050965.jpg
#   inflating: __MACOSX/large_prepared_data/val/._050965.jpg
#   inflating: large_prepared_data/val/008703.jpg
#   inflating: __MACOSX/large_prepared_data/val/._008703.jpg
#   inflating: large_prepared_data/val/157207.jpg
#   inflating: __MACOSX/large_prepared_data/val/._157207.jpg
#   inflating: large_prepared_data/val/127079.jpg
#   inflating: __MACOSX/large_prepared_data/val/._127079.jpg
#   inflating: large_prepared_data/val/190957.jpg
#   inflating: __MACOSX/large_prepared_data/val/._190957.jpg
#   inflating: large_prepared_data/val/045993.jpg
#   inflating: __MACOSX/large_prepared_data/val/._045993.jpg
#   inflating: large_prepared_data/val/020845.jpg
#   inflating: __MACOSX/large_prepared_data/val/._020845.jpg
#   inflating: large_prepared_data/val/106896.jpg
#   inflating: __MACOSX/large_prepared_data/val/._106896.jpg
#   inflating: large_prepared_data/val/202447.jpg
#   inflating: __MACOSX/large_prepared_data/val/._202447.jpg
#   inflating: large_prepared_data/val/160093.jpg
#   inflating: __MACOSX/large_prepared_data/val/._160093.jpg
#   inflating: large_prepared_data/val/049429.jpg
#   inflating: __MACOSX/large_prepared_data/val/._049429.jpg
#   inflating: large_prepared_data/val/154479.jpg
#   inflating: __MACOSX/large_prepared_data/val/._154479.jpg
#   inflating: large_prepared_data/val/023342.jpg
#   inflating: __MACOSX/large_prepared_data/val/._023342.jpg
#   inflating: large_prepared_data/val/012160.jpg
#   inflating: __MACOSX/large_prepared_data/val/._012160.jpg
#   inflating: large_prepared_data/val/131626.jpg
#   inflating: __MACOSX/large_prepared_data/val/._131626.jpg
#   inflating: large_prepared_data/val/099796.jpg
#   inflating: __MACOSX/large_prepared_data/val/._099796.jpg
#   inflating: large_prepared_data/val/106061.jpg
#   inflating: __MACOSX/large_prepared_data/val/._106061.jpg
#   inflating: large_prepared_data/val/162068.jpg
#   inflating: __MACOSX/large_prepared_data/val/._162068.jpg
#   inflating: large_prepared_data/val/064394.jpg
#   inflating: __MACOSX/large_prepared_data/val/._064394.jpg
#   inflating: large_prepared_data/val/151885.jpg
#   inflating: __MACOSX/large_prepared_data/val/._151885.jpg
#   inflating: large_prepared_data/val/042609.jpg
#   inflating: __MACOSX/large_prepared_data/val/._042609.jpg
#   inflating: large_prepared_data/val/029057.jpg
#   inflating: __MACOSX/large_prepared_data/val/._029057.jpg
#   inflating: large_prepared_data/val/082565.jpg
#   inflating: __MACOSX/large_prepared_data/val/._082565.jpg
#   inflating: large_prepared_data/val/153670.jpg
#   inflating: __MACOSX/large_prepared_data/val/._153670.jpg
#   inflating: large_prepared_data/val/090149.jpg
#   inflating: __MACOSX/large_prepared_data/val/._090149.jpg
#   inflating: large_prepared_data/val/055573.jpg
#   inflating: __MACOSX/large_prepared_data/val/._055573.jpg
#   inflating: large_prepared_data/val/023368.jpg
#   inflating: __MACOSX/large_prepared_data/val/._023368.jpg
#   inflating: large_prepared_data/val/002601.jpg
#   inflating: __MACOSX/large_prepared_data/val/._002601.jpg
#   inflating: large_prepared_data/val/040383.jpg
#   inflating: __MACOSX/large_prepared_data/val/._040383.jpg
#   inflating: large_prepared_data/val/193865.jpg
#   inflating: __MACOSX/large_prepared_data/val/._193865.jpg
#   inflating: large_prepared_data/val/185949.jpg
#   inflating: __MACOSX/large_prepared_data/val/._185949.jpg
#   inflating: large_prepared_data/val/025533.jpg
#   inflating: __MACOSX/large_prepared_data/val/._025533.jpg
#   inflating: large_prepared_data/val/015142.jpg
#   inflating: __MACOSX/large_prepared_data/val/._015142.jpg
#   inflating: large_prepared_data/val/055200.jpg
#   inflating: __MACOSX/large_prepared_data/val/._055200.jpg
#   inflating: large_prepared_data/val/081858.jpg
#   inflating: __MACOSX/large_prepared_data/val/._081858.jpg
#   inflating: large_prepared_data/val/084934.jpg
#   inflating: __MACOSX/large_prepared_data/val/._084934.jpg
#   inflating: large_prepared_data/val/031157.jpg
#   inflating: __MACOSX/large_prepared_data/val/._031157.jpg
#   inflating: large_prepared_data/val/012981.jpg
#   inflating: __MACOSX/large_prepared_data/val/._012981.jpg
#   inflating: large_prepared_data/val/149211.jpg
#   inflating: __MACOSX/large_prepared_data/val/._149211.jpg

# %% [markdown]
# # Example of typical data loader for images
#
# Below is an example typical data loader for images tasks. This might be useful for 1.1

# %%
class FaceDataset(Dataset): 
  def __init__(self, root_dir, transform=None):
    self.root_dir = root_dir
    self.transform = transform
    self.label_df = pd.read_csv(f'{self.root_dir}/label_df.csv')
  
  def __len__(self):
    return len(self.label_df)
  
  def __getitem__(self, idx): 
    data = self.label_df.iloc[idx]
    img = Image.open(f"{self.root_dir}/{data['filename']}").convert('RGB')
    if self.transform is not None: 
        transformed_img = self.transform(img) 
    else: 
        transformed_img = None 
    identity = data['identity']
    return transformed_img, identity, np.array(img)

# %% [markdown]
# This is an example to display a face image with its identity

# %%
import matplotlib.pyplot as plt 
face_dataset = FaceDataset(root_dir='large_prepared_data/test') 

for idx in range(4): 
  _, identity, img = face_dataset[idx]  
  plt.title(f'identity = {identity}')  
  plt.imshow(img)
  plt.show()

# %% [markdown]
# # Part 1: Face verification with contrastive loss
#
# The objective of the face verification task is to validate whether the face image $x$ has the identity $y$ by comparing it to the face database of the claimed identity. If the face similarity score between $x$ and the face in the database of $y$ is above a certain threshold, the image is then verified; otherwise, the identity is rejected.
#
# In HW3, you have learned to calculate a similarity score based on compact image representation using a PCA / Fisher projection. Therefore, in this part, you will instead implement a more contemporary method by training the NN to propose a compact representation (feature vector) by using a Siamese network and contrastive loss (Chopra et al., 2005, http://yann.lecun.com/exdb/publis/pdf/chopra-05.pdf).
#
# In contrast to the classification task that forces the model to learn all possible classes of objects, the general idea of object verification is based on contrastive learning, a framework that teaches the model to distinguish the two objects from each other. For a contrastive loss, the model will receive a pair of image and then learn to recognize whether both of them has the same identity by encouraging the feature vector of the same identity to come closer and different one to move away from each other.

# %% [markdown]
# ## 1.1 (TODO) Dataset and DataLoader
#
# First, we will start by writing a dataloader. The contrastive loss learns whether a pair of images have the same identity. Therefore, in this subsection, you have to write a dataloader that returns the tuple `(img1, img2, is_same_identity (bool))`.
#
# **File structure of this dataset**
# ```
# - large_prepared_data/
# └───train/
# |    - {img1}.jpg
# |    - {img2}.jpg
# |    - label_df.csv
# └───val/
# |    - {img3}.jpg
# |    - {img4}.jpg
# |    - label_df.csv
# └───test/
#     - {img5}.jpg
#     - {img6}.jpg
#     - label_df.csv
# ```
# **Note**
#
# label_df.csv has 2 columns that are the filename such as 001257.jpg and the identity such as 1691
#
#
# **Instructions**
#
# TODO 1-4: Fill in the missing code in the cells below. \
# TODO 1-2: Organize the dataset for simple data access. \
# TODO 3: Randomly select the datapoint from the dataset and format it to be ready for training. \
# TODO 4: Initialize the dataloader.

# %%
class SiameseDataset(Dataset):
    def __init__(self, root_dir, transform=None):
      '''
        The dataset of siamese network
        [Args]
        - root_dir = root directory of the dataset 
        - transform = transformations for images 
      ''' 
      np.random.seed(123)
      random.seed(123)
      self.root_dir = root_dir
      self.transform = transform

      label_df = pd.read_csv(f'{root_dir}/label_df.csv')
      self.num_images = len(label_df)
      label_df = label_df.groupby('identity')['filename'].apply(list).reset_index().rename({'filename': 'filenames'}, axis=1)
      self.load_images_to_memory_(label_df) 
        
    def load_images_to_memory_(self, label_df): 
      '''
        Load all images into memory 
        [Args]
        - label_df = The dataframe containing the identities and the filenames of images  
      '''
      # TODO 1: load images to `self.data` according to the structure below.
      # Convert images to RGB as well
      #   self.data = {
      #   'identity1': [image1, image2], 
      #   'identity2': [image3, image4, image5], 
      # }
      # identity{i}: str, image{i}: PIL.Image  
      self.data = None 
      self.images = None 
      self.identities = None  
   
      # TODO 2: save the list of identities found in self.identities (the keys)
      # in `self.unique_identities` as a numpy array.
      self.unique_identities = None 

    def __len__(self):
      return self.num_images 
        
    def __getitem__(self, idx): 
      '''
      Return a pair of image together with its label 
      [Args]
      - idx: int 
      [Return]
      - img1: torch.FloatTensor 
      - img2: torch.FloatTensor 
      - label: totch.FloatTensor = 1 (same class), 0 (different class)
      '''
      # TODO 3: randomly sample a pair of images 
      # Note: if idx is even, it should return the same class pair, otherwise a random pair.
      # Please use label = 1 for the same class pairs and label = 0 for the different class pairs 
      img1 = None 
      img2 = None 
      label = None
      return img1, img2, torch.from_numpy(np.array([label], dtype=np.float32))

# %%
img_size = 224
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(img_size),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                          std=[0.5, 0.5, 0.5])
])

val_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                          std=[0.5, 0.5, 0.5])
])

train_batch_size = 32
val_batch_size = 32
test_batch_size = 32 

# TODO 4: declare the datasets and the dataloaders. We already split the data
# for you in the zip file. Look at the directory names.
train_siamese_dataset = None 
train_siamese_dataloader = None 

val_siamese_dataset = None 
val_siamese_dataloader = None 

test_siamese_dataset = None 
test_siamese_dataloader = None

# %% [markdown]
# ## 1.2 (TODO) Siamese network
#
# After the dataloader is initialized, we then build a siamese network. Section 1.5 will explain how a siamese network works in full detail.
#
# Siamese network is a typical CNN that consists of three modules:
#
# 1. A feature extractor (ResNet18) for extracting the feature map from an image.
# 2. A global pooling for reducing the image dimension.
# 3. A fully connected layer for compressing the feature vector
#
# Every fully connected layer is followed by ReLU activations.
#
#
# TODO 5: Implement a siamese network based on the description.
#
# **Note**
# 1. You can use the ResNet18 from the `torchvision` library (How to use torchvision: https://pytorch.org/vision/stable/models.html)
# 2. We will not use pretrained weights.

# %% [markdown]
# Figure 1 Siamese network
#
# ![Screen Shot 2565-04-06 at 01.52.46.png](data:image/png;base64,...)

# %%
class SiameseNetwork(nn.Module):
  # TODO 5: implement the siamese network 
  def __init__(self):
      super().__init__()

  def extract_feature(self, x):
      output = None 
      return output

  def forward(self, input1, input2):
      output1 = None 
      output2 = None 
      return output1, output2

# %%
siamese_model = SiameseNetwork()

# %% [markdown]
# ## 1.3 (TODO) Constrastive loss
# A contrastive loss is a loss used to minimize the dissimilarity between two images by encouraging the feature vector of the same identity to come closer and different one further than a constant margin $m$ to move away from each other.
#
#
# The contrastive loss is mathematically defined as:

# %% [markdown]
# $
# L\ (contrastive\ loss ) = \begin{cases}
#                         d(r_1, r_2) & if\ identity(r1) = identity(r2) \\
#                         max(0, m - d(r_1, r_2)) & if\ identity(r1) \neq identity(r2) \\
#                     \end{cases}
# \
# $

# %% [markdown]
# where
#
# - $d(r_1, r_2)$ = euclidean distance between $r_1$ and $r_2$
# - $m$ = margin
# - $identity(x)$ = the identity of x
# - $r_1$ = the feature vector of the first image
# - $r_2$ = the feature vector of the second image

# %% [markdown]
# The term $d(r_1, r_2)$ is the distance between the two feature vectors. The contrastive loss minimizes the distance between the feature vectors of the same identity (positive pair) but maximizes the distance of the different identities (negative pair).
#
# The margin $m$ is used to prevent the loss from collapsing to a trivial solution. For instance, when $m = 0$, the model could achieve $L = 0$ just by exploiting the objective by setting $r_1 = r_2$, and the model, as a result, would learn nothing useful.
#
# **HINT**
#
# Many torch functions often have the same functionality as NumPy functions, even sharing the same function name. Therefore, if you are struggling with this part, you might write the loss using NumPy first and then convert it to the torch function (https://pytorch.org/docs/stable/torch.html) later.
# **Avoid using "if statements" to make the training faster. You have already learned many tricks that convert if statements into a single equation.**

# %% [markdown]
# TODO 6: Implement a contrastive loss based on the description above.

# %%
class ContrastiveLoss(torch.nn.Module):
  # TODO 6: implement the contrastive loss 
  def __init__(self, margin):
    super().__init__()

  def forward(self, output1, output2, label):
    loss_contrastive = None 
    return loss_contrastive

# %%
siamese_margin = 2.0
siamese_criterion = ContrastiveLoss(margin=siamese_margin)

# %% [markdown]
# ## 1.4 Initiaze model parameter

# %%
siamese_optimizer = optim.Adam(siamese_model.parameters(), lr=1e-4)
siamese_scheduler = optim.lr_scheduler.ReduceLROnPlateau(siamese_optimizer, 'min', patience=5, factor=0.1, min_lr=1e-8)

# %% [markdown]
# ## 1.5 (TODO) Training loop
#
# The training procedure of a siamese network consists of the following steps:
#
# 1. Forward pass the `img1`.
# 2. Forward pass the `img2`.
# 3. Calculate the distance between the feature vector of `img1` and `img2` $(d(r_1, r_2))$.
# 4. Use the distance in step 3 as a loss and update the model.
# 5. Repeat step 1-4 until satisfied.
#
# As you would notice, both first and second step shares the same network weights. Therefore, the word "Siamese" in the siamese network originates from the "Siamese twins" since the network performs two forward passes to compare whether the feature vectors have the same identity by using the same set of network parameters (shared parameters).
#
# TODO 7-8: Feed pairs of images to the network, compute contrastive loss to measure the dissimilarity of pairs of face images and update the network.
#
# TODO 9: Feed a pair of images from validation set to the network and compute the validation loss.
#
# **Trivia**
#
# The Siamese twin is a conjoined twin brother born in Siam who later move to the US (https://th.wikipedia.org/wiki/%E0%B8%AD%E0%B8%B4%E0%B8%99-%E0%B8%88%E0%B8%B1%E0%B8%99).

# %%
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"
siamese_model.to(device)

os.makedirs('weights', exist_ok=True)
best_weights_path = 'weights/best_siamese_weights.pth' 

train_losses = [] 
val_losses = [] 
min_val_loss = float('inf')

for epoch in tqdm(range(num_epochs)): 
    siamese_model.train() 
    total_train_loss = 0 
      
    
    for img1, img2, label in train_siamese_dataloader:

        # TODO 7: feed data to model and compute loss 
        pass

        # TODO 8: back propagate
        pass 

        total_train_loss += train_loss.item()


    current_train_loss = total_train_loss / len(train_siamese_dataloader) 
    train_losses.append(current_train_loss) 
            
    total_val_loss = 0 
    siamese_model.eval() 
    for val_img1, val_img2, val_label in val_siamese_dataloader:  

        # TODO 9: feed data to model and compute loss 
        pass

        total_val_loss += val_loss.item()
    current_val_loss = total_val_loss / len(val_siamese_dataloader)
    val_losses.append(current_val_loss) 
    if current_val_loss < min_val_loss: 
        min_val_loss = current_val_loss 
        torch.save(siamese_model.state_dict(), best_weights_path)
    print(f'Epoch {epoch+1} - Train loss = {current_train_loss:.4f} - Val loss = {current_val_loss:.4f} - best min_val_loss = {min_val_loss:.4f} - lr = {siamese_optimizer.param_groups[0]["lr"]:.8f}') 
    siamese_scheduler.step(current_val_loss)

# %% [markdown]
# ## 1.6 Visualization
#
# This visualization displays pairs of images together with the distance between those pairs.

# %%
# Showing images
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(120, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
        
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    


siamese_model.load_state_dict(torch.load(best_weights_path))
siamese_model.eval() 

test_img1s, test_img2s, test_labels = next(iter(test_siamese_dataloader))
test_img1s, test_img2s, test_labels = test_img1s.to(device), test_img2s.to(device), test_labels.to(device)
with torch.no_grad(): 
    test_out1s, test_out2s = siamese_model(test_img1s, test_img2s)  

class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor

unnormalizer = UnNormalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
      
for test_out1, test_out2, test_img1, test_img2, test_label in zip(test_out1s, test_out2s, test_img1s, test_img2s, test_labels):  
    test_img1 = unnormalizer(test_img1.detach().cpu().unsqueeze(0))
    test_img2 = unnormalizer(test_img2.detach().cpu().unsqueeze(0))
    concatenated = torch.cat((test_img1, test_img2), 0)
    distance = F.pairwise_distance(test_out1, test_out2) 
    imshow(torchvision.utils.make_grid(concatenated), f'Label = {int(test_label[0])}, Distance: {distance.item():.4f}')

# %% [markdown]
# ## 1.7 Plot loss history

# %%
plt.plot(np.arange(1, len(train_losses)+1), train_losses, label='train loss') 
plt.plot(np.arange(1, len(val_losses)+1), val_losses, label='val loss') 
plt.legend()
plt.show()

# %% [markdown]
# ## 1.8 (TODO) Plot t-SNE
#
# After the training process is finished, we evaluate whether the learned representation is informative. In this task, embedding visualization is often performed to verify that the feature learned by the network is behaving as intended, i.e., feature vectors of the same identity should be close to each other and far away from other identities. Since the feature vector dimension is too high for a human to interpret, therefore, in this assignment, we use the t-SNE dimensionality reduction technique to compress the feature into a 2D space.
#
#
# **Instructions**
#
# TODO 10: Extract the feature vectors of the test set and store them as
#
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
#
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
#
# **Hint**
# Use `FaceDataset` that is imported at `Common Dataset` section
#
# **WARNING!!**
# Don't forget load its best weights and change to eval mode first

# %%
test_batch_size = 32 

# TODO 10: Extract the feature vectors of the test set and store them as 
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set 
# Hint      => Use `FaceDataset` that is imported at `Common Dataset` section 
# WARNING!! => Don't forget load its best weights and change to eval mode first 

embeddings = None 
identities = None

# %%
import time 
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings, identities)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

# %%
import plotly.express as px

# relabel to be easier to see in t-SNE visualization 
label = [] 
idx = 0 
id2label = dict() 
for identity in identities: 
  identity = int(identity) 
  if identity not in id2label:
    id2label[identity] = idx 
    idx += 1 
  label.append(id2label[identity])

df_subset = pd.DataFrame({'label': label})

df_subset['tsne-2d-one'] = tsne_result[:,0]
df_subset['tsne-2d-two'] = tsne_result[:,1]

fig = px.scatter(df_subset, x="tsne-2d-one", y="tsne-2d-two", color="label", height=1000, width=1000)
fig.show()

# %% [markdown]
# ## 1.9 (TODO) Analyzing feature vector visualization result

# %% [markdown]
# TODO 11: What could you say about the displayed visualization? Is the model working as expected?
#
# Answer here:

# %% [markdown]
# # Part 2: Face verification with triplet loss + center loss
#
#
# In contrast to contrastive loss which learns to distinguish whether the two images have the same identity, triplet loss is proposed as an alternative by introducing an anchor image as a third input. Triplet loss receives three inputs: anchor, positive pair, and negative pair. The positive pair is an image having the same identity as the anchor while the negative pair is the one with a different identity. The loss learns to minimize the distance between the anchor and positive pair, and maximize the distance between the anchor and the negative pair. Compared to contrastive loss, triplet loss offers more training stability and better model performance.
#
# Nevertheless, both contrastive and triplet loss also has some shortcomings as these losses only optimize on a pairwise level. This might result in feature vectors of the same identity taking the form of multiple small clusters scattering across the feature space since there is no explicit loss to bind them into a single group. Therefore, a center loss is proposed to mitigate this problem by encouraging the intra-class (same identity) feature vectors to come closer to their intra-class centroids.
#
# In this part, you are going to implement a face verification network by jointly training **three losses**: triplet, center, and cross-entropy loss.

# %% [markdown]
# ## 2.1 (TODO) Dataset and DataLoader
#
# In this section, you are going to implement a dataloader for the combined loss.
# The dataloader should return the tuple `(anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label)`.
#
# TODO 12-15: Fill in the missing code in the cells below. \
# TODO 12-13: Organize the dataset for simple data access. \
# TODO 14: Randomly select the datapoint from the dataset and format it to be ready for training.
# - The positive image must have the same identity as the anchor image.
# - The negative image must have a different identity from the anchor image. \
# - HINT: The NumPy function `np.where` might be useful.
#
# TODO 15: Initialize the dataloader.

# %%
class TripletDataset(Dataset):
    def __init__(self, root_dir, transform=None):
      np.random.seed(123)
      random.seed(123)
      self.root_dir = root_dir
      self.transform = transform
      
      label_df = pd.read_csv(f'{root_dir}/label_df.csv')
      label_df = label_df.groupby('identity')['filename'].apply(list).reset_index().rename({'filename': 'filenames'}, axis=1)
      self.images = [] 
      self.labels = [] 
      self.label2indices = dict() 
      self.load_images_to_memory_(label_df) 
      
    def load_images_to_memory_(self, label_df):  
      # TODO 12: load images and labels into memory  
      # We have to relabel from identities to 0,1,2,...,num_classes-1
      # Relevant variables 
      # 1. `self.images` = PIL images  (Also convert it to RGB)
      # 2. `self.label2indices` = the dictionary storing a label as a key and the indices of images as value 
      # 3. `self.labels` = labels of images (relabeled) 
      # Note: the index of images is from iterating over label_df   
      self.images = None 
      self.label2indices = None 
      self.labels = None 
     

    def __len__(self):
      return len(self.images) 
        
    def __getitem__(self, idx): 
      # TODO 13: generate an anchor image, a positive image and a negative image together with anchor_label 
      # anchor image is the image according to idx 
      # positive image is the image that has the same identity with the anchor image 
      # negative image is the image that has the different identity with the anchor image 
      anchor_img = None 
      pos_img = None 
      neg_img = None 
      anchor_label = None 
      pos_label = None 
      neg_label = None 


      # TODO 14: utilize `self.transform' to convert images to tensors 
      pass 

      return anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label

# %%
image_size = 224
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(image_size),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                          std=[0.5, 0.5, 0.5])
])

val_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                          std=[0.5, 0.5, 0.5])
])

train_batch_size = 16
val_batch_size = 16
test_batch_size = 16

# TODO 15: declare the datasets and the dataloaders 
train_triplet_dataset = None 
train_triplet_dataloader = None 

val_triplet_dataset = None 
val_triplet_dataloader = None 

test_triplet_dataset = None 
test_triplet_dataloader = None

# %% [markdown]
# ## 2.2 (TODO) Triplet Network
#
# Triplet network is a simplified version of a strong baseline person re-identification task (ref: https://arxiv.org/abs/1903.07071). The model uses the extracted features to calculate the main triplet loss with center loss to reduce intra-class distance and a classification output head to calculate a classification loss.
#
# Triplet network consists of three modules
# 1. Feature extractor (ResNet18) for mapping an image to a feature map.
# 2. Global pooling (Global average pooling or use flatten instead) for converting a feature map to a feature vector.
# 3. Bottleneck (Batch normalization with scaling shift only, no bias shift) for training consistency between triplet loss and cross-entropy as optimizing both losses in embedding space at the same time is difficult.
# 4. Linear classifier for classifying the face identity.
#
# As illustration of a triplet net is shown below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note**
# 1. ResNet18 can be called via the `torchvision` library (How to use torchvision: https://pytorch.org/vision/stable/models.html)
# 2. We use will not load pre-trained weights for ResNet18
# 3. We will only use ResNet18 to extract feature maps.
#
# **Hint**
# 1. For global average pooling, read the documentation of `nn.AdaptiveAvgPool2d`
# 2. For bottleneck, try the `requires_grad_` method to stop calculating gradient for the bias shift.
#
#
# TODO 16-17: Implement the triplet network.

# %%
class TripletNetwork(nn.Module):
  # TODO 16: implement the triplet network 
  def __init__(self, num_classes):
    super().__init__()

  def extract_feature(self, x):
    global_feat = None 
    cls_score = None 
    return global_feat, cls_score

  def forward(self, anchor_img, pos_img, neg_img): 
    anchor_feat, pos_feat, neg_feat, feats, scores  = None, None, None, None, None 
    return anchor_feat, pos_feat, neg_feat, feats, scores

# %%
# TODO 17: get the number of classes to construct a linear classifier and the parameters in center loss 
num_classes = None 
print(f'num_classes = {num_classes}') 

triplet_model = TripletNetwork(num_classes)

# %% [markdown]
# ## 2.3 (TODO) Triplet loss
#
# Triplet loss uses the same concept as contrastive loss that is the anchor image will pull the positive one closer and push the negative one further than the constant margin away. Hence, we have sampled three images to compute it.
# The three images consist of:
# 1. an anchor image = an initial image
# 2. a positive image = the image having the same identity as the anchor image
# 3. a negative image = the image having a different identity from the anchor image
#
# The triplet loss is mathematically defined as:
#
# $L_{Triplet} = max(0, m + d(r_a, r_p) - d(r_a, r_n))$
#
# where
# - $d(r_1, r_2)$ = euclidean distance between $r_1$ and $r_2$
# - $m$ = margin
# - $r_a$ = the feature vector of the anchor image
# - $r_p$ = the feature vector of the positive image
# - $r_n$ = the feature vector of the negative image
#
# The loss aims to minimize $d(r_a, r_p)$ while maximizing $d(r_a, r_n)$ at the same time.
#
# The margin $m$ is used to prevent the loss from collapsing to a trivial solution. For instance, when $m = 0$, the model could achieve $L = 0$ just by exploiting the objective by setting $r_a = r_p = r_n$, and the model, as a result, would learn nothing useful.
#
# TODDO 18: Implement the triplet loss

# %%
class TripletLoss(nn.Module):
  # TODO 18: implement the triplet loss 
  def __init__(self, margin=2.0):  
    super().__init__()
      
  def forward(self, anchor_img, pos_img, neg_img):
    return

# %%
triplet_margin = 3.0
triplet_criterion = TripletLoss(margin=triplet_margin)

# %% [markdown]
# ## 2.4 (TODO) Center loss
# Reference: https://ydwen.github.io/papers/WenECCV16.pdf
#
# **Definition**
#
# Centroid: a representative of each class. There are several ways to select a representative, one way to do this is to take an average on those embeddings.
#
# **Concept**
#
# Center loss enforces the intra-class feature vectors to come closer to the centroid of their class so that all feature vectors of the same identity are clustered around a single centroid. Since the model is updated after each iteration, the centroids should also be updated accordingly. However, re-calculating the centroids by averaging the feature vectors for each class every iteration is computational-extensive on a large scale. Therefore, the centroid is instead learned from the representative of each class from the sampled data.
#
# **Implementation detail**
#
# In `__init__` method
#   1. For simplicity, we will store the centroids in the class `CenterLoss`. Therefore, you have to initialize the centroids as a random tensor with the size of `(num_classes, feature_dimension)`. The tensor has to be set with `nn.Paramater` so that the gradient could be calculated (ref: https://pytorch.org/docs/stable/generated/torch.nn.parameter.Parameter.html).
#
# In the `forward` method
#   1. Calculate the distance between the feature vector and its center with a squared Euclidean distance
#   2. Clip the value in each element to be not greater than 1e+12, not lower than 1e-12, and sum them
#   3. Normalize the loss with its batch size
#
# **Center loss equation**
#
# $L_{Center} = \frac{1}{B}\sum_{j=1}^{B}||f_{j} - c_{y_j}||_2^2$
#
# where
# - $f_{j}$ = a feature vector before fed into the bottleneck at index $j$
# - $c_{y_j}$ = a center of the class corresponded to the index $j$
# - B = batch size
#
# The center loss minimized the distance between the feature vector and the centroid of the corresponded identity.
#
# **Note**
# 1. At `__init__` method in step 1. Do not forget to transfer the parameters to GPU with `.cuda()` otherwise, it will not utilize GPU on this part.
# 2. Clip the magnitude of the loss at the final stage before updating both upper bound and lower bound to avoid vanishing / exploding gradients.
#
# **Hint**
# 1. In step 2 of the `forward` method, you should use `torch.clamp` (ref: https://pytorch.org/docs/stable/generated/torch.clamp.html) to clip the lower bound and the upper bound as you want.

# %%
class CenterLoss(nn.Module): 
  # TODO 19: implement the center loss 
  def __init__(self, num_classes, feat_dim):  
    super().__init__()
   
  def forward(self, x, labels):  
    return

# %%
 triplet_center_criterion = CenterLoss(num_classes, feat_dim=512)

# %% [markdown]
# ## 2.5 (TODO) Declare cross entropy criterions, optimizers and scheduler

# %%
triplet_optimizer = optim.Adam(triplet_model.parameters(), lr=5e-5)
triplet_scheduler = optim.lr_scheduler.ReduceLROnPlateau(triplet_optimizer, 'min', patience=4, factor=0.1, min_lr=1e-8) 

# TODO 20: declare cross entropy loss 
crossentropy_criterion = None 

triplet_center_optimizer = optim.Adam(triplet_center_criterion.parameters(), lr=5e-2)
triplet_center_loss_weight = 5e-3

# %% [markdown]
# ## 2.6 (TODO) Training loop

# %% [markdown]
# The figure below shows how the center loss is updated in the original paper. $L_s$ $L_c$, $W$, $\theta_c$ and $c_j$ stand for classification loss, center loss, classification head's weight, CNN weight, and centroid of the class $j$, respectively. Line 6 shows how centroids are updated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Joint loss equation**
#
# $L_{Joint} = L_{ID} + L_{Triplet} + \beta L_{Center}$
#
# where
# - $L_{Joint}$ = joint loss
# - $L_{ID}$ = identity loss (cross entropy loss in this implementation)
# - $L_{Triplet}$ = triplet loss
# - $L_{Center}$ = center loss
# - $\beta$ = center loss weights (affects only the triplet network, not center update)

# %% [markdown]
# The training procedure of the triplet network consists of the following steps:
#
# 1. Forward pass the `anchor_img`
# 2. Forward pass the `positive_img`
# 3. Forward pass the `negative_img`
# 4. Calculate the distance between the feature vectors of `anchor_img`, `positive_img` and `negative_img` and calculate a triplet loss ($L_{Triplet}$).
# 5. Calculate the classification loss ($L_{ID}$).
# 6. Calculate the center loss ($L_{Center}$).
# 7. Scale the center loss with the predetermined weight ($\beta$) (only used to update the triplet network not to update the centroids).
# 8. Sum the losses from steps 4-7 and update the triplet network. (Line 3-5)
# 9. Rescale the gradients with $\frac{1}{\beta}$ at the loss in step 7 and update the centroids. (Line 6-7)
# 10. Repeat steps 1-9 till converge
#
# As you would notice, steps 1- 3 share the same model weight for feature extraction. Thus, the word "triplet" in triplet loss originates in a similar fashion as the "Siamese twins" but this loss function utilizes three feature vectors simultaneously instead of two.
#
#
#
# TODO 21 (step 1-4): extract feature vectors of three images and compute triplet loss
#
# TODO 22 (step 5): calculate cross-entropy loss from the output of the classification head.
#
# TODO 23 (step 6-7): compute the center loss by feeding both features and their labels and scale it with the center loss weights ($\beta$)
#
# TODO 24 (step 8): set zero gradients at both optimizers
#
# TODO 25 (step 8): update the joint loss and step the triplet optimizer
#
# TODO 26 (step 9): rescale the gradients of centroids with $\frac{1}{\beta}$ and update the centroids with rescaled gradients
#
# TODO 27: feed anchor images, positive images, and negative images from the validation set to extract feature vectors and compute validation triplet loss
#
# **Hint**
#
# 1. At the gradient rescaling for the centroids, we should iterate parameters in center loss first with `.parameters()` and adjust the property of each parameter with `.grad.data`

# %%
num_epochs = 20 
device = "cuda" if torch.cuda.is_available() else "cpu"

os.makedirs('weights', exist_ok=True)
best_weights_path = 'weights/best_triplet_weights.pth' 
triplet_model.to(device)
min_val_loss = float('inf')

train_losses = [] 
train_triplet_losses = [] 
train_crossentropy_losses = []  
train_center_losses = [] 

val_losses = [] 
val_triplet_losses = [] 

for epoch in tqdm(range(num_epochs)): 
    triplet_model.train() 
    total_train_loss = 0 
    total_train_triplet_loss = 0
    total_train_crossentropy_loss = 0
    total_train_center_loss = 0 
    for anchor_img, pos_img, neg_img, anchor_label, pos_label, neg_label in tqdm(train_triplet_dataloader):

        # TODO 21: feed data to the triplet model and compute triplet loss 
        pass 

        # TODO 22: compute cross entropy loss 
        pass         

        # TODO 23: compute center loss 
        pass 

        train_loss = train_triplet_loss + train_crossentropy_loss + train_center_loss 
        total_train_loss += train_loss.item() 
        total_train_triplet_loss += train_triplet_loss.item()
        total_train_crossentropy_loss += train_crossentropy_loss.item()
        total_train_center_loss += train_center_loss.item()

        # TODO 24: set zero gradients at two optimizers 
        pass 

        # TODO 25 : back propagate at triplet network and step the main optimizer 
        pass 

        # TODO 26: rescale gradients of centers because `triplet_center_loss_weight` should not affect to learning the centers 
        # and step the center optimizer 
        pass 

    current_train_loss = total_train_loss / len(train_triplet_dataloader) 
    current_train_triplet_loss = total_train_triplet_loss / len(train_triplet_dataloader) 
    current_train_crossentropy_loss = total_train_crossentropy_loss / len(train_triplet_dataloader) 
    current_train_center_loss = total_train_center_loss / len(train_triplet_dataloader) 
    train_losses.append(current_train_loss)
    train_triplet_losses.append(current_train_triplet_loss)
    train_crossentropy_losses.append(current_train_crossentropy_loss) 
    train_center_losses.append(current_train_center_loss)            
            
    total_val_loss = 0 
    total_val_triplet_loss = 0 
    triplet_model.eval() 
    for val_anchor_img, val_pos_img, val_neg_img, _, _, _ in val_triplet_dataloader:  

      # TODO 27: feed data to the triplet model and compute triplet loss   
      pass 
      
      val_loss = val_triplet_loss 
      total_val_loss += val_loss.item()
      total_val_triplet_loss += val_triplet_loss.item()
    current_val_loss = total_val_loss / len(val_triplet_dataloader)
    current_val_triplet_loss = total_val_triplet_loss / len(val_triplet_dataloader)
    val_losses.append(current_val_loss)
    val_triplet_losses.append(current_val_triplet_loss)
    
    if current_val_loss < min_val_loss: 
        min_val_loss = current_val_loss 
        torch.save(triplet_model.state_dict(), best_weights_path)
    print(f'Epoch {epoch+1} - Train loss = {current_train_loss:.4f} - Train triplet loss = {current_train_triplet_loss:.4f} - Train crossentropy loss = {current_train_crossentropy_loss:.4f}  - Train center loss = {current_train_center_loss:.4f} - Val loss = {current_val_loss:.4f} - Val triplet loss = {current_val_triplet_loss:.4f} - best min_val_loss = {min_val_loss:.4f} - lr = {triplet_optimizer.param_groups[0]["lr"]:.8f}') 
    triplet_scheduler.step(current_val_loss)

# %% [markdown]
# ## 2.7 Visualization
#
# The visualization below displays an anchor, positive, and negative image and their respective distance.

# %%
# Showing images
def imshow(img, text=None):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(20, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
        
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

best_weights_path = 'weights/best_triplet_weights.pth' 
triplet_model.to(device)
triplet_model.load_state_dict(torch.load(best_weights_path))
triplet_model.eval() 

test_anchor_imgs, test_pos_imgs, test_neg_imgs, test_anchor_ids, _, _ = next(iter(test_triplet_dataloader))
test_anchor_imgs, test_pos_imgs, test_neg_imgs = test_anchor_imgs.to(device), test_pos_imgs.to(device), test_neg_imgs.to(device)
with torch.no_grad(): 
    test_anchor_feats, test_pos_feats, test_neg_feats, _, _ = triplet_model(test_anchor_imgs, test_pos_imgs, test_neg_imgs)  

class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # The normalize code -> t.sub_(m).div_(s)
        return tensor

unnormalizer = UnNormalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])

zip_test_data = zip(test_anchor_feats, test_pos_feats, test_neg_feats, test_anchor_imgs, test_pos_imgs, test_neg_imgs)      
for test_anchor_feat, test_pos_feat, test_neg_feat, test_anchor_img, test_pos_img, test_neg_img in zip_test_data:  
    test_anchor_img = unnormalizer(test_anchor_img.detach().cpu().unsqueeze(0))
    test_pos_img = unnormalizer(test_pos_img.detach().cpu().unsqueeze(0))
    test_neg_img = unnormalizer(test_neg_img.detach().cpu().unsqueeze(0))
    concatenated = torch.cat((test_anchor_img, test_pos_img, test_neg_img), 0)
    anc_pos_distance = F.pairwise_distance(test_anchor_feat, test_pos_feat) 
    anc_neg_distance = F.pairwise_distance(test_anchor_feat, test_neg_feat) 
    imshow(torchvision.utils.make_grid(concatenated), f'Anc-Pos Distance: {anc_pos_distance.item():.4f}, Anc-Neg Distance: {anc_neg_distance.item():.4f}')

# %% [markdown]
# ## 2.8 Plot loss history

# %%
import matplotlib.pyplot as plt 
plt.plot(np.arange(1, len(train_losses)+1), train_losses, label='train loss') 
plt.plot(np.arange(1, len(val_losses)+1), val_losses, label='val loss') 
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot(np.arange(1, len(train_losses)+1), train_triplet_losses, label='train triplet loss') 
plt.plot(np.arange(1, len(val_losses)+1), val_triplet_losses, label='val triplet loss') 
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.plot(np.arange(1, len(train_losses)+1), train_center_losses, label='train center loss') 
plt.legend()
plt.show()

# %% [markdown]
# ## 2.9 (TODO) Plot t-SNE
#
# This section is similar to section 1.8 but the network is instead optimized using a combined triplet, center, and cross-entropy loss.
#
# **Instructions**
#
# TODO 28: Extract the feature vectors of the test set and store them as
#
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
#
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set
#
# **Hint**
# Use `FaceDataset` that is imported at `Common Dataset` section
#
# **WARNING!!**
# Don't forget load its best weights and change to eval mode first

# %%
test_batch_size = 32 

# TODO 28: Extract the feature vectors of the test set and store them as 
# `embeddings`: torch.FloatTensor = feature vectors of all images in the test set
# `identities`: list or torch.Tensor or np.array = identities of all images in the test set 
# Hint      => Use `FaceDataset` that is imported at `Common Dataset` section 
# WARNING!! => Don't forget load its best weights and change to eval mode first 

embeddings = None 
identities = None

# %%
import time 
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

# %%
import plotly.express as px

label = [] 
idx = 0 
id2label = dict() 
for identity in identities: 
  identity = int(identity) 
  if identity not in id2label:
    id2label[identity] = idx 
    idx += 1 
  label.append(id2label[identity])

df_subset = pd.DataFrame({'label': label})

df_subset['tsne-2d-one'] = tsne_result[:,0]
df_subset['tsne-2d-two'] = tsne_result[:,1]

fig = px.scatter(df_subset, x="tsne-2d-one", y="tsne-2d-two", color="label", height=1000, width=1000)
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %%
import time 
from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=3, verbose=1, perplexity=30, n_iter=3000)
tsne_result = tsne.fit_transform(embeddings)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

# %%
import plotly.express as px

label = [] 
idx = 0 
id2label = dict() 
for identity in identities: 
  identity = int(identity) 
  if identity not in id2label:
    id2label[identity] = idx 
    idx += 1 
  label.append(id2label[identity])

df_subset = pd.DataFrame({'label': label})

df_subset['tsne-3d-one'] = tsne_result[:,0]
df_subset['tsne-3d-two'] = tsne_result[:,1]
df_subset['tsne-3d-three'] = tsne_result[:,2]

fig = px.scatter_3d(df_subset, x="tsne-3d-one", y="tsne-3d-two", z="tsne-3d-three", color="label")
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()

# %% [markdown]
# ## 2.10 (TODO) Embedding comparision

# %% [markdown]
# TODO 29: Compare the visualization of the triplet network to the siamese network. Which one is better and why?
#
# Answer here:

# %% [markdown]
# ## (Optional) Try other tricks to get higher quality of face embeddings such as
# 1. GeM Pooling (ref: https://amaarora.github.io/2020/08/30/gempool.html)
# 2. Arcface (ref: https://arxiv.org/abs/1801.07698)
# 3. Hard negative mining (ref: https://omoindrot.github.io/triplet-loss (TF implementation))
# 4. Online hard negative mininig (ref: https://gist.github.com/erogol/c37628286f8efdb62b3cc87aad382f9e (Pytorch implementation))
# 5. Semi-hard mining
#
# and plot t-SNE to compare with vanilla triplet loss

# %%
pass

# %% [markdown]
# # Part 3 Face verification evaluation
#
# In HW3, we use ROC curve to measure the performance of face verfication task. Similarly, we will use this mertic to measure the performance of our NN.
#
# TODO 30: Use both siamese and triplet network to extract the image features from the test set.

# %%
val_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                          std=[0.5, 0.5, 0.5])
])


test_siamese_dataset = SiameseDataset(root_dir='large_prepared_data/test', transform=val_transform)
test_siamese_dataloader = DataLoader(test_siamese_dataset, batch_size=test_batch_size, shuffle=False, num_workers=2)

siamese_embeddings1 = [] 
siamese_embeddings2 = [] 
triplet_embeddings1 = [] 
triplet_embeddings2 = [] 
labels = [] 

device = 'cuda' if torch.cuda.is_available() else 'cpu' 

siamese_model.load_state_dict(torch.load('weights/best_siamese_weights.pth')) 
triplet_model.load_state_dict(torch.load('weights/best_triplet_weights.pth'))
siamese_model.eval()
triplet_model.eval()

siamese_scores = [] 
triplet_scores = [] 

for batch_img1, batch_img2, batch_label in tqdm(test_siamese_dataloader):
  batch_img1, batch_img2, batch_label = batch_img1.to(device), batch_img2.to(device), batch_label.to(device) 
  with torch.no_grad(): 
    # TODO 30: extract features with both siamese network and triplet network 
    # and keep embeddings in provided lists according to variable names 
    siamese_embeddings1.append(None)
    siamese_embeddings2.append(None)
    triplet_embeddings1.append(None)
    triplet_embeddings2.append(None)
    
  labels.append(batch_label)

siamese_embeddings1 = torch.cat(siamese_embeddings1)
siamese_embeddings2 = torch.cat(siamese_embeddings2)
triplet_embeddings1 = torch.cat(triplet_embeddings1)
triplet_embeddings2 = torch.cat(triplet_embeddings2)
labels = torch.cat(labels)

# %% [markdown]
# TODO 31: Measure the similarity score between the two feature vectors with cosine similarity.
#
# **HINT**
# You can use `nn.CosineSimilarity`
# (ref: https://pytorch.org/docs/stable/generated/torch.nn.CosineSimilarity.html).

# %%
def compute_pairs_cosine_sim(input1, input2): 
  # TODO 31: implement cosine similarity function that can compute multiple pairs at the same time
  pass

# %%
siamese_scores = compute_pairs_cosine_sim(siamese_embeddings1, siamese_embeddings2)  
triplet_scores = compute_pairs_cosine_sim(triplet_embeddings1, triplet_embeddings2)

# %% [markdown]
# TODO 32
#
# Plot a ROC curve to compare the performance between siamese and triplet networks. Which one is better and why?

# %%
import matplotlib.pyplot as plt 
# TODO 32: calculate true positive rate and false positive rate 
# and plot both the ROC curve of siamese network and the ROC curve of triplet network 
# together with AUC score
